# %% [markdown]
# #### Capstone 2 Arima Model

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib  as mpl 
# %matplotlib inline

# Load Specific forecasting tools
from statsmodels.tsa.arima_model import ARIMA,ARIMAResults, ARIMA, ARIMAResults
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima import auto_arima

import itertools
import statsmodels.api as sm
plt.style.use('fivethirtyeight')
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# Ignore harmless warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### DATA CLEANING AND EXPLORATORY DATA ANALYSIS

# %%
#get data
eurusd = pd.read_csv(r'eurusd.csv', index_col=0, parse_dates=True, skipinitialspace=True)

# %%
# Examine firt 5 rows
eurusd.head()
# Out:
#               Open    High     Low   close  Change  Volume
# date
# 2000-01-03  1.0085  1.0280  1.0055  1.0256  0.0168       0
# 2000-01-04  1.0255  1.0340  1.0217  1.0301  0.0045       0
# 2000-01-05  1.0304  1.0400  1.0289  1.0315  0.0014       0
# 2000-01-06  1.0320  1.0413  1.0283  1.0315  0.0000       0
# 2000-01-07  1.0317  1.0333  1.0263  1.0296 -0.0019       0

# %%
# Examine last five rows
eurusd.tail()
# Out:
#                Open     High      Low    close   Change  Volume
# date
# 2019-12-20  1.11197  1.11246  1.10661  1.10748 -0.00448  119919
# 2019-12-23  1.10822  1.10954  1.10697  1.10884  0.00136  109071
# 2019-12-24  1.10882  1.10937  1.10693  1.10877 -0.00007  102337
# 2019-12-26  1.10925  1.11115  1.10819  1.10952  0.00075   59499
# 2019-12-27  1.10953  1.11878  1.10939  1.11726  0.00774  157620

# %%
# Examine index
eurusd.index
# Out:
# DatetimeIndex(['2000-01-03', '2000-01-04', '2000-01-05', '2000-01-06',
#                '2000-01-07', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14',
#                ...
#                '2019-12-13', '2019-12-16', '2019-12-17', '2019-12-18',
#                '2019-12-19', '2019-12-20', '2019-12-23', '2019-12-24',
#                '2019-12-26', '2019-12-27'],
#               dtype='datetime64[ns]', name='date', length=5187, freq=None)

# %%
# Examine data types
eurusd.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# close     float64
# Change    float64
# Volume      int64
# dtype: object

# %%
# Select column 'Open' for analysis
eurusdopen = eurusd.Open

# %%
# Get summary statistics
eurusdopen.describe()
# Out:
# count    5187.000000
# mean        1.209273
# std         0.166635
# min         0.826600
# 25%         1.110315
# 50%         1.225800
# 75%         1.331520
# max         1.599100
# Name: Open, dtype: float64

# %%
# Check for missing data
print(eurusd.isnull().sum())
# Out:
# Open      0
# High      0
# Low       0
# close     0
# Change    0
# Volume    0
# dtype: int64

# %% [markdown]
# There are no missing values in the data set

# %%
# Examine distribution
eurusdopen.hist()

# %%
# Plot the exchange rate for 'open column'

eurusd['Open'].plot(ylim=[0,1.75],figsize = (12,5)).autoscale(axis='x', tight=True)
plt.title('Exchange Rate Chart', size=20)
plt.xlabel('Years', size=17)
plt.ylabel('Exchange Rate', size=17)
plt.autoscale(enable=True, axis='x', tight=True)
plt.tick_params(labelsize=14)

# %%
# Carry out Decomposition

seasonal = seasonal_decompose(eurusd.Open, model='multiplicative', freq=52)
seasonal.plot()
mpl.rcParams['figure.figsize'] = 12,6

# %% [markdown]
# STATIONARITY

# %%
# Examine the trend of the mean and standard deviation to examine impact on exchange rate trend

eurusd['12-month-SMA(Open)'] = eurusd['Open'].rolling(window=12).mean()
eurusd['12-month-std(Open)'] = eurusd['Open'].rolling(window=12).std()
eurusd[['Open', '12-month-SMA(Open)', '12-month-std(Open)']].plot()
plt.ylim(0, 2)
plt.xlabel('Years', size=17)
plt.ylabel('Exchange Rate', size=17)
plt.autoscale(enable=True, axis='x', tight=True)#plt.axis('tight'
plt.tick_params(labelsize=14)
mpl.rcParams['figure.figsize'] = 12,6

# %% [markdown]
# From the chart above, it is clear that the Standard deviation is stationary, while the mean is not. The mean actually varies with the exchange rate trend

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue

# %%
mod = sm.tsa.statespace.SARIMAX(eurusd.Open,
                                order=(1, 0, 0),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9989      0.001   1753.875      0.000       0.998       1.000
# ar.S.L12      -0.0134      0.012     -1.134      0.257      -0.037       0.010
# ma.S.L12      -0.9981      0.007   -152.219      0.000      -1.011      -0.985
# sigma2      5.526e-05   8.15e-07     67.829      0.000    5.37e-05    5.69e-05
# ==============================================================================

# %%
# Diagnostics of results
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %% [markdown]
# Our primary concern is to ensure that the residuals of our model are uncorrelated and normally distributed with zero-mean. If the seasonal ARIMA model does not satisfy these properties, it is a good indication that it can be further improved.
#
# In this case, our model diagnostics suggests that the model residuals are normally distributed based on the following:
#
# In the top right plot, we see that the red KDE line follows closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). This is a good indication that the residuals are normally distributed.
# The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) follows the linear trend of the samples taken from a standard normal distribution with N(0, 1). Again, this is a strong indication that the residuals are normally distributed.
# The residuals over time (top left plot) don’t display any obvious seasonality and appear to be white noise. This is confirmed by the autocorrelation (i.e. correlogram) plot on the bottom right, which shows that the time series residuals have low correlation with lagged versions of itself.
#
# Those observations lead us to conclude that our model produces a satisfactory fit that could help us understand our time series data and forecast future values.

# %%
eurusd['d1Open'] = eurusd['Open'].diff()
eurusd['d1Open'].plot(title='First order difference').autoscale(axis='x', tight='True')

# %%
eurusd['12-month-SMA(Open)'] = eurusd['d1Open'].rolling(window=12).mean()
eurusd['12-month-std(Open)'] = eurusd['d1Open'].rolling(window=12).std()
eurusd[['d1Open', '12-month-SMA(Open)', '12-month-std(Open)']].plot()
plt.xlabel('Years', size=17)
plt.ylabel('Exchange Rate', size=17)
plt.autoscale(enable=True, axis='x', tight=True)#plt.axis('tight'
plt.tick_params(labelsize=14)
mpl.rcParams['figure.figsize'] = 12,6

# %%
print('Augmented Dickey-Fuller Test on EURUSD Exchange Rate Data')
dftest = adfuller(eurusd['Open'], autolag='AIC')
dftest
# Out:
# Augmented Dickey-Fuller Test on EURUSD Exchange Rate Data
# (-1.7766411806819693,
#  0.39211880218374784,
#  0,
#  5186,
#  {'1%': -3.4316115772743645,
#   '5%': -2.8620974851364487,
#   '10%': -2.567066749257732},
#  -35890.06074673519)

# %% [markdown]
# Hypothesis Testing:
#
# The Null hypothesis of this project states that the time series data of eurysd is non-stationary. Using the Dickey fuller test, I will determine below whether or not this is true.

# %%
stepwise_fit = auto_arima(eurusd['Open'], start_P = 1, start_q = 1, max_p = 3, max_q = 3, m=12, start_p = 0, seasonal =True
                          , d=None, D=1, trace=True, 
                           error_action='ignore', # We don't want to know if an order does not work
                           surpress_warnings=True, #We don't want convergence warnings
                           stepwise=True) #Set to stepwise
stepwise_fit.summary()
# Out:
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=-27750.573, BIC=-27717.815, Fit time=55.235 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=-23285.648, BIC=-23272.545, Fit time=2.740 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=-34037.982, BIC=-34011.776, Fit time=34.137 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=-27752.181, BIC=-27725.975, Fit time=43.098 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=-23287.328, BIC=-23280.776, Fit time=0.962 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=-32618.739, BIC=-32599.084, Fit time=2.117 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=-34615.960, BIC=-34583.202, Fit time=162.753 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(2, 1, 1, 12); AIC=-35597.560, BIC=-35558.250, Fit time=163.757 seconds
# Near non-invertible roots for order (1, 0, 0)(2, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.991)
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=-35914.820, BIC=-35882.062, Fit time=96.468 seconds
# Near non-invertible roots for order (1, 0, 0)(1, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=-23288.483, BIC=-23262.277, Fit time=17.080 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(2, 1, 0, 12); AIC=-34482.383, BIC=-34443.073, Fit time=183.122 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(2, 1, 0, 12); AIC=-34480.325, BIC=-34441.016, Fit time=190.122 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(2, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(2, 1, 0, 12); AIC=-34530.171, BIC=-34484.310, Fit time=295.848 seconds
# Total fit time: 1266.548 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 5187
# Model:             SARIMAX(1, 0, 0)x(1, 1, 1, 12)   Log Likelihood               17962.410
# Date:                            Tue, 07 Jan 2020   AIC                         -35914.820
# Time:                                    13:56:48   BIC                         -35882.062
# Sample:                                         0   HQIC                        -35903.359
#                                            - 5187
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -2.546e-06    1.7e-06     -1.499      0.134   -5.88e-06    7.84e-07
# ar.L1          0.9959      0.001   1489.286      0.000       0.995       0.997
# ar.S.L12      -0.0320      0.012     -2.617      0.009      -0.056      -0.008
# ma.S.L12      -0.9989      0.010   -102.963      0.000      -1.018      -0.980
# sigma2      5.715e-05   9.55e-07     59.865      0.000    5.53e-05     5.9e-05
# ===================================================================================
# Ljung-Box (Q):                       56.49   Jarque-Bera (JB):               898.95
# Prob(Q):                              0.04   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.69   Skew:                             0.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
print('Augmented Dickey-Fuller Test on EURUSD Exchange Rate Data')
dfout = pd.Series(dftest[0:4], index = ['ADF Test Statistic', 'p-value', '# lags used', '# observations'])

for key, val in dftest[4].items():
    dfout[f'critical value({key})']=val
    print(dfout)
# Out:
# Augmented Dickey-Fuller Test on EURUSD Exchange Rate Data
# ADF Test Statistic      -1.776641
# p-value                  0.392119
# # lags used              0.000000
# # observations        5186.000000
# critical value(1%)      -3.431612
# dtype: float64
# ADF Test Statistic      -1.776641
# p-value                  0.392119
# # lags used              0.000000
# # observations        5186.000000
# critical value(1%)      -3.431612
# critical value(5%)      -2.862097
# dtype: float64
# ADF Test Statistic       -1.776641
# p-value                   0.392119
# # lags used               0.000000
# # observations         5186.000000
# critical value(1%)       -3.431612
# critical value(5%)       -2.862097
# critical value(10%)      -2.567067
# dtype: float64

# %% [markdown]
# The P-value above is greater than 5% using the dickey fuller test, hence we accept the null-hypothesis to be true, that our time series data for eurusd is non-stationary

# %% [markdown]
# MACHINE LEARNING

# %% [markdown]
# #### SARIMAX MODEL

# %%
eurusd.shape
# Out:
# (5187, 9)

# %%
# Split Dataset into training and test using a 70% split in favor of train
size = int(len(eurusd.Open) * 0.70)
train, test = eurusd.Open[0:size], eurusd.Open[size:len(eurusd.Open)]

# %%
# Import SARIMAX 

from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# Fit SARIMAX model
model  = SARIMAX(train, order=(1,0,0), seasonal_order=(1,1,1,12), enforce_invertibility=False)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                               Open   No. Observations:                 3630
# Model:             SARIMAX(1, 0, 0)x(1, 1, 1, 12)   Log Likelihood               12301.710
# Date:                            Tue, 07 Jan 2020   AIC                         -24595.420
# Time:                                    14:08:06   BIC                         -24570.645
# Sample:                                         0   HQIC                        -24586.593
#                                            - 3630
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9983      0.001   1031.377      0.000       0.996       1.000
# ar.S.L12      -0.0084      0.014     -0.583      0.560      -0.037       0.020
# ma.S.L12      -0.9965      0.007   -150.509      0.000      -1.009      -0.984
# sigma2      6.407e-05   1.15e-06     55.760      0.000    6.18e-05    6.63e-05
# ===================================================================================
# Ljung-Box (Q):                       46.14   Jarque-Bera (JB):               409.46
# Prob(Q):                              0.23   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.42   Skew:                             0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Make predictions
start = len(train)
end = len(train) + len(test)-1
predictions = results.predict(start = start, end = end, dynamic = False, typ='levels').rename('SARIMAX(1,0,0) Predictions')

# %%
# Define expected
expected=test

# %%
# Forcast error
for i in range(len(predictions)):
    Forecast_error = predictions[i] - test[i]

# %%
# Plot predictions against known values
ax = test.plot(legend=True, figsize=(12,6))
predictions.plot(legend=True)
ax.autoscale(axis = 'x', tight=True)

# %%
# Compare predictions to expected values

for i in range(len(predictions)):
    print(f"predicted={predictions[i]}, \t expected={test[i]}")
# Out:
# predicted=1.368819690108401, 	 expected=1.3681
# predicted=1.3686641375061241, 	 expected=1.36897
# predicted=1.3696474512888783, 	 expected=1.37494
# predicted=1.3753100122157849, 	 expected=1.38012
# predicted=1.3801991901136041, 	 expected=1.37409
# predicted=1.3742503344490633, 	 expected=1.36714
# predicted=1.3676293077441162, 	 expected=1.3591
# predicted=1.3581191555424457, 	 expected=1.36277
# predicted=1.3629689726136092, 	 expected=1.36148
# predicted=1.3609513142917011, 	 expected=1.3576
# predicted=1.3574845815780257, 	 expected=1.3608
# predicted=1.2689999089135133, 	 expected=1.26844
# predicted=1.2685764955069476, 	 expected=1.26302
# predicted=1.2637075058986016, 	 expected=1.262
# predicted=1.2611359311062111, 	 expected=1.2668
# predicted=1.2671158053760692, 	 expected=1.2511
# predicted=1.250584320151068, 	 expected=1.26549
# predicted=1.2655640739713288, 	 expected=1.26685
# predicted=1.2660226481135597, 	 expected=1.2732700000000001
# predicted=1.2728202308821683, 	 expected=1.26902
# predicted=1.2697094811079102, 	 expected=1.2634
# predicted=1.2642615014163547, 	 expected=1.2751
# predicted=1.275626049273941, 	 expected=1.2657100000000001
# predicted=1.2658279287073555, 	 expected=1.28372
# predicted=1.2839641971603852, 	 expected=1.28083
# predicted=1.2814579180554082, 	 expected=1.2744
# predicted=1.2735030450400855, 	 expected=1.27993
# predicted=1.280260735407596, 	 expected=1.27159
# predicted=1.2709883500077332, 	 expected=1.2648
# predicted=1.264738913713314, 	 expected=1.2645899999999999
# predicted=1.2637301030543908, 	 expected=1.268
# predicted=1.2675959054335473, 	 expected=1.26981
# predicted=1.2704633896162425, 	 expected=1.27339
# predicted=1.2740822837983192, 	 expected=1.26309
# predicted=1.263638143016939, 	 expected=1.26128
# predicted=1.261217378204993, 	 expected=1.2501
# predicted=1.2503350833633144, 	 expected=1.24807
# predicted=1.2487806895566296, 	 expected=1.25458
# predicted=1.2537167035270993, 	 expected=1.2484899999999999
# predicted=1.2487252264980933, 	 expected=1.2374399999999999
# predicted=1.2371372977261526, 	 expected=1.24787
# predicted=1.2478476080352792, 	 expected=1.24201
# predicted=1.2412296000516165, 	 expected=1.24722
# predicted=1.2467646321174453, 	 expected=1.2438
# predicted=1.2443679761669164, 	 expected=1.2475
# predicted=1.248476793377636, 	 expected=1.2531
# predicted=1.2535490724736267, 	 expected=1.245
# predicted=1.2453078551892964, 	 expected=1.2536100000000001
# predicted=1.2538223699739022, 	 expected=1.25529
# predicted=1.2558399880985267, 	 expected=1.2538
# predicted=1.2530755896523658, 	 expected=1.2362
# predicted=1.236445969320265, 	 expected=1.24415
# predicted=1.2436468293623875, 	 expected=1.2473
# predicted=1.247333986115993, 	 expected=1.2505
# predicted=1.2497075048400148, 	 expected=1.24664
# predicted=1.2462454298686672, 	 expected=1.2472
# predicted=1.247773988609313, 	 expected=1.24685
# predicted=1.2476305599815372, 	 expected=1.23829
# predicted=1.2388097639896232, 	 expected=1.23101
# predicted=1.231096361235918, 	 expected=1.23779
# predicted=1.2379745798476542, 	 expected=1.22821
# predicted=1.2288891567048899, 	 expected=1.23166
# predicted=1.231055244207616, 	 expected=1.23737
# predicted=1.2373866355753005, 	 expected=1.2446
# predicted=1.2442066199286042, 	 expected=1.2409299999999999
# predicted=1.2408602140719571, 	 expected=1.2473
# predicted=1.2466218895847687, 	 expected=1.24359
# predicted=1.243148604655545, 	 expected=1.251
# predicted=1.2516210154192937, 	 expected=1.234
# predicted=1.234951961199699, 	 expected=1.2285
# predicted=1.2289924042101765, 	 expected=1.2220799999999998
# predicted=1.2222239038698863, 	 expected=1.22282
# predicted=1.2231380811808676, 	 expected=1.2171399999999999
# predicted=1.2177747196413513, 	 expected=1.2221
# predicted=1.221214832287022, 	 expected=1.218
# predicted=1.2180719878208714, 	 expected=1.2151
# predicted=1.2148183984507026, 	 expected=1.21541
# predicted=1.215347381707866, 	 expected=1.21015
# predicted=1.2094992241705786, 	 expected=1.20013
# predicted=1.1996704393032458, 	 expected=1.19313
# predicted=1.19397541888047, 	 expected=1.1889100000000001
# predicted=1.1898470532545586, 	 expected=1.18382
# predicted=1.1843249439027637, 	 expected=1.17916
# predicted=1.1794331241267069, 	 expected=1.1852
# predicted=1.1854855001015105, 	 expected=1.18329
# predicted=1.1839558380579456, 	 expected=1.17723
# predicted=1.1765135846615902, 	 expected=1.1788
# predicted=1.1790399405422023, 	 expected=1.163
# predicted=1.1627232584940428, 	 expected=1.1545
# predicted=1.1546411256664277, 	 expected=1.1605
# predicted=1.159955280472558, 	 expected=1.15483
# predicted=1.154590392716708, 	 expected=1.16091
# predicted=1.161601770976828, 	 expected=1.13647
# predicted=1.1374375657693365, 	 expected=1.11558
# predicted=1.1161172329829503, 	 expected=1.12384
# predicted=1.12412177485163, 	 expected=1.138
# predicted=1.1382784265100354, 	 expected=1.1287
# predicted=1.1295494703964688, 	 expected=1.1318
# predicted=1.1310646720978677, 	 expected=1.1311
# predicted=1.13150948547766, 	 expected=1.13402
# predicted=1.1338649641953584, 	 expected=1.1477700000000002
# predicted=1.1477882742083814, 	 expected=1.13424
# predicted=1.133648097503717, 	 expected=1.1476600000000001
# predicted=1.1472749501979282, 	 expected=1.1291
# predicted=1.1300111245941216, 	 expected=1.13232
# predicted=1.1334295402131052, 	 expected=1.13199
# predicted=1.1323638416936324, 	 expected=1.13354
# predicted=1.133750995569189, 	 expected=1.1401
# predicted=1.1404430487403663, 	 expected=1.1406
# predicted=1.1413223307220715, 	 expected=1.1352
# predicted=1.1344922680204084, 	 expected=1.141
# predicted=1.141156968155473, 	 expected=1.1396
# predicted=1.1391885710150456, 	 expected=1.13673
# predicted=1.1369757521024473, 	 expected=1.14
# predicted=1.1391942466454603, 	 expected=1.13337
# predicted=1.1332685997312117, 	 expected=1.13391
# predicted=1.1344531636180388, 	 expected=1.13606
# predicted=1.1368847343699924, 	 expected=1.11969
# predicted=1.1201708686598504, 	 expected=1.1175
# predicted=1.1178518367510186, 	 expected=1.1182
# predicted=1.1184354994193073, 	 expected=1.11745
# predicted=1.118289996733886, 	 expected=1.10766
# predicted=1.1069167870791625, 	 expected=1.1027
# predicted=1.1029504891865483, 	 expected=1.0828
# predicted=1.0826639463534529, 	 expected=1.0850799999999998
# predicted=1.0851661413388844, 	 expected=1.0697
# predicted=1.0692185774497662, 	 expected=1.0547
# predicted=1.0544289465304868, 	 expected=1.0634
# predicted=1.064038484702419, 	 expected=1.0462
# predicted=1.0472772696798762, 	 expected=1.0566799999999998
# predicted=1.0572695758415984, 	 expected=1.05965
# predicted=1.0601438659334552, 	 expected=1.08616
# predicted=1.0864435311387062, 	 expected=1.0659
# predicted=1.0668180354209096, 	 expected=1.0838
# predicted=1.0832127247243553, 	 expected=1.0945
# predicted=1.1358900677535102, 	 expected=1.13788
# predicted=1.1371732162287664, 	 expected=1.13402
# predicted=1.1338409484643324, 	 expected=1.11665
# predicted=1.116984240970587, 	 expected=1.1203
# predicted=1.1211072851295831, 	 expected=1.12025
# predicted=1.120742567009449, 	 expected=1.10056
# predicted=1.1010793794877622, 	 expected=1.1235
# predicted=1.1237010862552337, 	 expected=1.1138
# predicted=1.1145393661190226, 	 expected=1.1052
# predicted=1.104639654946161, 	 expected=1.1083
# predicted=1.1083624267335703, 	 expected=1.0992600000000001
# predicted=1.0991973687200227, 	 expected=1.10551
# predicted=1.1055813823552547, 	 expected=1.1011
# predicted=1.1004234467315466, 	 expected=1.1075
# predicted=1.1073158320128154, 	 expected=1.1035
# predicted=1.1040908736174644, 	 expected=1.1102
# predicted=1.1110043365382933, 	 expected=1.1
# predicted=1.1007652156050465, 	 expected=1.10079
# predicted=1.1009884520670807, 	 expected=1.09464
# predicted=1.094903347911324, 	 expected=1.08742
# predicted=1.088372176895109, 	 expected=1.08314
# predicted=1.0825234587219665, 	 expected=1.0824
# predicted=1.0827035050360239, 	 expected=1.09345
# predicted=1.0933633744339446, 	 expected=1.0928
# predicted=1.0929547793054337, 	 expected=1.0983
# predicted=1.0975130778567352, 	 expected=1.0979999999999999
# predicted=1.0976341343623852, 	 expected=1.1087
# predicted=1.109265101553561, 	 expected=1.1059299999999999
# predicted=1.106838270196894, 	 expected=1.09818
# predicted=1.0986726981774009, 	 expected=1.0931
# predicted=1.093675728701366, 	 expected=1.09785
# predicted=1.0980518828634014, 	 expected=1.0949
# predicted=1.0957689784695648, 	 expected=1.08805
# predicted=1.0874796352254077, 	 expected=1.0904
# predicted=1.090461748094011, 	 expected=1.0924
# predicted=1.092405290782126, 	 expected=1.09679
# predicted=1.0968256257827886, 	 expected=1.10181
# predicted=1.1011109056531516, 	 expected=1.1041
# predicted=1.10356758180437, 	 expected=1.1156
# predicted=1.1162735362916727, 	 expected=1.11497
# predicted=1.1158067270010417, 	 expected=1.1111
# predicted=1.1116389680881218, 	 expected=1.1075
# predicted=1.107928139091353, 	 expected=1.10217
# predicted=1.1022993336927889, 	 expected=1.11188
# predicted=1.1127392806641196, 	 expected=1.1239299999999999
# predicted=1.1232894381744325, 	 expected=1.13757
# predicted=1.1377090455450674, 	 expected=1.1616
# predicted=1.1614782211188859, 	 expected=1.1514
# predicted=1.151400196501556, 	 expected=1.1313
# predicted=1.1305445132072856, 	 expected=1.12471
# predicted=1.124184949575122, 	 expected=1.1173
# predicted=1.1179385350582993, 	 expected=1.1209
# predicted=1.121662424371664, 	 expected=1.13127
# predicted=1.131753464890724, 	 expected=1.12252
# predicted=1.1230478472634147, 	 expected=1.1122299999999998
# predicted=1.1122106614341285, 	 expected=1.1156
# predicted=1.1162388647967307, 	 expected=1.11687
# predicted=1.1161326537500806, 	 expected=1.12006
# predicted=1.12000124921523, 	 expected=1.12058
# predicted=1.1206633116869542, 	 expected=1.1279
# predicted=1.1281945811515792, 	 expected=1.133
# predicted=1.1323419572233684, 	 expected=1.13147
# predicted=1.0943715207453588, 	 expected=1.0974
# predicted=1.0977584195681473, 	 expected=1.09901
# predicted=1.0991822006258622, 	 expected=1.0927799999999999
# predicted=1.0936864190073166, 	 expected=1.091
# predicted=1.0903743136604114, 	 expected=1.0825
# predicted=1.0828197328575702, 	 expected=1.08648
# predicted=1.0862129306916524, 	 expected=1.0913899999999999
# predicted=1.0915114310478418, 	 expected=1.0956299999999999
# predicted=1.0949376412858678, 	 expected=1.091
# predicted=1.0905113401840545, 	 expected=1.095
# predicted=1.095546060123563, 	 expected=1.0966
# predicted=1.097422263914583, 	 expected=1.09168
# predicted=1.0919943029854278, 	 expected=1.0931
# predicted=1.0934250410772008, 	 expected=1.0856
# predicted=1.0858190108272117, 	 expected=1.0828
# predicted=1.0837061588762038, 	 expected=1.0747
# predicted=1.0742636154888454, 	 expected=1.07806
# predicted=1.0783194744581177, 	 expected=1.0927
# predicted=1.0928154576928046, 	 expected=1.0915
# predicted=1.0914800176707855, 	 expected=1.0858299999999999
# predicted=1.0851551980736307, 	 expected=1.0857299999999999
# predicted=1.085282563173018, 	 expected=1.0875
# predicted=1.0882140825536444, 	 expected=1.0864200000000002
# predicted=1.0871890193497755, 	 expected=1.0927
# predicted=1.093043449046288, 	 expected=1.0890799999999998
# predicted=1.0895059491745738, 	 expected=1.0907
# predicted=1.090857788836277, 	 expected=1.0885
# predicted=1.0894554139946613, 	 expected=1.0874
# predicted=1.0868035339444668, 	 expected=1.07917
# predicted=1.0793324464020921, 	 expected=1.0847
# predicted=1.0849016199603472, 	 expected=1.0867799999999999
# predicted=1.0868795372909816, 	 expected=1.08924
# predicted=1.0885027786712662, 	 expected=1.0938
# predicted=1.0933811925548154, 	 expected=1.08334
# predicted=1.0840887289537628, 	 expected=1.08856
# predicted=1.0891946402936, 	 expected=1.09174
# predicted=1.0921391031365422, 	 expected=1.11047
# predicted=1.1107546206867547, 	 expected=1.12076
# predicted=1.120869734307983, 	 expected=1.1145
# predicted=1.115326803197297, 	 expected=1.11922
# predicted=1.1187198307241417, 	 expected=1.12923
# predicted=1.129478627428083, 	 expected=1.1291200000000001
# predicted=1.1292362837098966, 	 expected=1.1320000000000001
# predicted=1.131949787329219, 	 expected=1.12333
# predicted=1.1225110091828232, 	 expected=1.1154
# predicted=1.1150892142690634, 	 expected=1.11432
# predicted=1.114965688384556, 	 expected=1.1126
# predicted=1.1132587894894836, 	 expected=1.1105399999999999
# predicted=1.110679017543056, 	 expected=1.1117
# predicted=1.111899379719251, 	 expected=1.10274
# predicted=1.1029022487241846, 	 expected=1.10165
# predicted=1.1024248267161774, 	 expected=1.1012
# predicted=1.1005082054577102, 	 expected=1.1015700000000002
# predicted=1.1019220530791545, 	 expected=1.0919
# predicted=1.0920537987296688, 	 expected=1.0871899999999999
# predicted=1.087308359049942, 	 expected=1.08644
# predicted=1.0858044342560695, 	 expected=1.08683
# predicted=1.0864211151891803, 	 expected=1.09556
# predicted=1.0963107491237347, 	 expected=1.09883
# predicted=1.0995646383892423, 	 expected=1.1012
# predicted=1.101587873778729, 	 expected=1.101
# predicted=1.1014392564903055, 	 expected=1.0997
# predicted=1.0997922946160477, 	 expected=1.1176700000000002
# predicted=1.1184932348352046, 	 expected=1.1129
# predicted=1.1123287596652576, 	 expected=1.1101
# predicted=1.110538963341187, 	 expected=1.1108
# predicted=1.1110201039185894, 	 expected=1.1224
# predicted=1.1223721740446526, 	 expected=1.13162
# predicted=1.1308282575533517, 	 expected=1.1257
# predicted=1.1251480101226856, 	 expected=1.12402
# predicted=1.1246817750592635, 	 expected=1.12166
# predicted=1.12231625904485, 	 expected=1.1179999999999999
# predicted=1.1183863494046997, 	 expected=1.1172
# predicted=1.1175135955798772, 	 expected=1.11615
# predicted=1.1160271680241025, 	 expected=1.1193
# predicted=1.120161013629095, 	 expected=1.1288
# predicted=1.1282468579029137, 	 expected=1.1336
# predicted=1.1338753525187562, 	 expected=1.1379
# predicted=1.137908912548242, 	 expected=1.139
# predicted=1.13885014792947, 	 expected=1.13852
# predicted=1.137788229254733, 	 expected=1.1382299999999999
# predicted=1.137800065912123, 	 expected=1.13983
# predicted=1.1405401644317994, 	 expected=1.1376
# predicted=1.138305750673933, 	 expected=1.1415600000000001
# predicted=1.1419250682767677, 	 expected=1.1404299999999998
# predicted=1.1407106934630096, 	 expected=1.13856
# predicted=1.138622449433424, 	 expected=1.1272
# predicted=1.127889104159334, 	 expected=1.1266200000000002
# predicted=1.1259843337976825, 	 expected=1.1306
# predicted=1.1308429688607637, 	 expected=1.131
# predicted=1.131160362201162, 	 expected=1.1357
# predicted=1.1356825471382381, 	 expected=1.1295
# predicted=1.1287036698421204, 	 expected=1.1284
# predicted=1.1279429808682273, 	 expected=1.1218700000000001
# predicted=1.122587894429853, 	 expected=1.1271
# predicted=1.1277250622255763, 	 expected=1.1297
# predicted=1.1300770129392217, 	 expected=1.1321
# predicted=1.1323933112746767, 	 expected=1.1348200000000002
# predicted=1.1350438120537427, 	 expected=1.1449799999999999
# predicted=1.1457811035142695, 	 expected=1.153
# predicted=1.1523620503469638, 	 expected=1.1496
# predicted=1.1498755067527862, 	 expected=1.14857
# predicted=1.1486780208250718, 	 expected=1.14046
# predicted=1.1404942505790634, 	 expected=1.1392
# predicted=1.138403297060804, 	 expected=1.1383
# predicted=1.137921969336023, 	 expected=1.13713
# predicted=1.1377462960914093, 	 expected=1.1425
# predicted=1.1431333602605178, 	 expected=1.1375
# predicted=1.137828002834492, 	 expected=1.13032
# predicted=1.1305615930557906, 	 expected=1.13195
# predicted=1.1319202970387565, 	 expected=1.1312
# predicted=1.1319235577113766, 	 expected=1.12151
# predicted=1.1209955211470437, 	 expected=1.12019
# predicted=1.1205117102404447, 	 expected=1.12061
# predicted=1.1208930893726234, 	 expected=1.12195
# predicted=1.1219335345572026, 	 expected=1.114
# predicted=1.1132271323836875, 	 expected=1.1153600000000001
# predicted=1.1149319100733532, 	 expected=1.1193
# predicted=1.1199486466673287, 	 expected=1.1115
# predicted=1.1122501444459814, 	 expected=1.11376
# predicted=1.1142176379084126, 	 expected=1.1131
# predicted=1.1133791745996877, 	 expected=1.11853
# predicted=1.1186587988328782, 	 expected=1.1149799999999999
# predicted=1.1159251700347, 	 expected=1.1345
# predicted=1.1339415507445836, 	 expected=1.1354
# predicted=1.1356866989382968, 	 expected=1.1355899999999999
# predicted=1.135734032624031, 	 expected=1.13937
# predicted=1.139399357528903, 	 expected=1.13163
# predicted=1.1308151541739762, 	 expected=1.1248
# predicted=1.1243076273666428, 	 expected=1.1289200000000001
# predicted=1.129708116310068, 	 expected=1.1205
# predicted=1.121148385982865, 	 expected=1.12584
# predicted=1.1261939403767425, 	 expected=1.1224299999999998
# predicted=1.1226650298427079, 	 expected=1.1319
# predicted=1.132040392765971, 	 expected=1.13132
# predicted=1.1319157559989228, 	 expected=1.12416
# predicted=1.1235873365077569, 	 expected=1.12939
# predicted=1.1296856934310873, 	 expected=1.1375
# predicted=1.1376207176169943, 	 expected=1.10095
# predicted=1.1009924602481709, 	 expected=1.1022299999999998
# predicted=1.1015369605984222, 	 expected=1.10639
# predicted=1.1059296258839233, 	 expected=1.1122
# predicted=1.1129846002306405, 	 expected=1.1105
# predicted=1.1111327195084584, 	 expected=1.11228
# predicted=1.1126730937184675, 	 expected=1.1151799999999998
# predicted=1.1153981383586478, 	 expected=1.1073
# predicted=1.1074243765490153, 	 expected=1.1098
# predicted=1.1107516793716596, 	 expected=1.1061
# predicted=1.1055073389945975, 	 expected=1.1048200000000001
# predicted=1.105060883320714, 	 expected=1.1056700000000002
# predicted=1.106248353705183, 	 expected=1.1058
# predicted=1.1057207399606441, 	 expected=1.10877
# predicted=1.1079384634452487, 	 expected=1.1118
# predicted=1.111331534512171, 	 expected=1.10513
# predicted=1.105824259259356, 	 expected=1.1074700000000002
# predicted=1.1081575649621829, 	 expected=1.10198
# predicted=1.1023076845374202, 	 expected=1.10127
# predicted=1.101709995692867, 	 expected=1.10255
# predicted=1.1026461066536126, 	 expected=1.09764
# predicted=1.0985436554759176, 	 expected=1.09942
# predicted=1.0989199171474102, 	 expected=1.09854
# predicted=1.098887342457662, 	 expected=1.10569
# predicted=1.1057751092910517, 	 expected=1.10759
# predicted=1.1074958359873877, 	 expected=1.11699
# predicted=1.116177092879313, 	 expected=1.11584
# predicted=1.1155147553361964, 	 expected=1.1222
# predicted=1.1228271292422525, 	 expected=1.11484
# predicted=1.115597498888443, 	 expected=1.11261
# predicted=1.1129715703351266, 	 expected=1.1077
# predicted=1.108013070702712, 	 expected=1.10869
# predicted=1.1088630122468193, 	 expected=1.11143
# predicted=1.1122483237537975, 	 expected=1.11745
# predicted=1.1169241190009456, 	 expected=1.11361
# predicted=1.1138784790969014, 	 expected=1.11669
# predicted=1.116745371742889, 	 expected=1.11816
# predicted=1.117998531293751, 	 expected=1.1276899999999999
# predicted=1.1269205322405647, 	 expected=1.1289
# predicted=1.1284072049657534, 	 expected=1.13533
# predicted=1.136047475441874, 	 expected=1.13058
# predicted=1.1312672394223302, 	 expected=1.1319
# predicted=1.132280277125512, 	 expected=1.13044
# predicted=1.1307346754679486, 	 expected=1.12624
# predicted=1.126299664264542, 	 expected=1.12849
# predicted=1.1292495704851606, 	 expected=1.11834
# predicted=1.1178420635249189, 	 expected=1.1187799999999999
# predicted=1.119106307864194, 	 expected=1.11427
# predicted=1.114338086490445, 	 expected=1.11569
# predicted=1.1155601790210619, 	 expected=1.1196
# predicted=1.118813683650596, 	 expected=1.1149799999999999
# predicted=1.1145230593101834, 	 expected=1.11459
# predicted=1.1152770441064732, 	 expected=1.1255
# predicted=1.126146830914878, 	 expected=1.1238
# predicted=1.1241365097789144, 	 expected=1.126
# predicted=1.1263544240630547, 	 expected=1.12379
# predicted=1.1238655953226309, 	 expected=1.12337
# predicted=1.124317028390278, 	 expected=1.12182
# predicted=1.121263869779375, 	 expected=1.12477
# predicted=1.1251762882425793, 	 expected=1.1243
# predicted=1.1243623500862603, 	 expected=1.11556
# predicted=1.1155186269800168, 	 expected=1.1172799999999998
# predicted=1.1165623263990374, 	 expected=1.11494
# predicted=1.114575039517799, 	 expected=1.119
# predicted=1.1195049864690552, 	 expected=1.1207
# predicted=1.1213851071233734, 	 expected=1.12263
# predicted=1.122924691071474, 	 expected=1.1253799999999998
# predicted=1.1257002873683633, 	 expected=1.12124
# predicted=1.1213526165028957, 	 expected=1.1217
# predicted=1.1225255344746934, 	 expected=1.122
# predicted=1.1214210744681312, 	 expected=1.12278
# predicted=1.1231313347947562, 	 expected=1.12104
# predicted=1.1212140980786083, 	 expected=1.12037
# predicted=1.1203584587246198, 	 expected=1.1203
# predicted=1.1195433766362552, 	 expected=1.1149
# predicted=1.1144894128923777, 	 expected=1.11805
# predicted=1.1186833327731414, 	 expected=1.1136
# predicted=1.1142480189877195, 	 expected=1.10531
# predicted=1.1056236741649967, 	 expected=1.1007799999999999
# predicted=1.101138385448149, 	 expected=1.10544
# predicted=1.105558870240088, 	 expected=1.0968799999999999
# predicted=1.0977056482704, 	 expected=1.0999
# predicted=1.099378170601861, 	 expected=1.0978299999999999
# predicted=1.0982185052837892, 	 expected=1.0972600000000001
# predicted=1.097348642606448, 	 expected=1.09274
# predicted=1.0927818212875222, 	 expected=1.08812
# predicted=1.0874241554025277, 	 expected=1.08808
# predicted=1.0877216342963103, 	 expected=1.0886
# predicted=1.0893313182657876, 	 expected=1.0907
# predicted=1.0914814834530393, 	 expected=1.0896
# predicted=1.0900131016273191, 	 expected=1.09869
# predicted=1.0989465107665122, 	 expected=1.09794
# predicted=1.0981606815445768, 	 expected=1.1056
# predicted=1.1063871149118805, 	 expected=1.1096
# predicted=1.1091014503615848, 	 expected=1.1103299999999998
# predicted=1.1106867429172522, 	 expected=1.1067
# predicted=1.106815968458189, 	 expected=1.1039299999999999
# predicted=1.1040065538644552, 	 expected=1.1027
# predicted=1.1019191435068323, 	 expected=1.0908
# predicted=1.0904771781199531, 	 expected=1.08915
# predicted=1.089797579044653, 	 expected=1.08301
# predicted=1.0836976110468017, 	 expected=1.0736
# predicted=1.073875119667737, 	 expected=1.0722
# predicted=1.0725543346290056, 	 expected=1.069
# predicted=1.0690576369983, 	 expected=1.06233
# predicted=1.0631603439348818, 	 expected=1.05984
# predicted=1.0593609104942867, 	 expected=1.0628
# predicted=1.0632359596463463, 	 expected=1.06247
# predicted=1.0626006175803648, 	 expected=1.0559
# predicted=1.0559782228071324, 	 expected=1.05511
# predicted=1.054503985815547, 	 expected=1.06168
# predicted=1.061413263904413, 	 expected=1.0607
# predicted=1.0614672086330568, 	 expected=1.06483
# predicted=1.0656168539926794, 	 expected=1.05892
# predicted=1.0593465639380015, 	 expected=1.0659999999999998
# predicted=1.066383020450497, 	 expected=1.06426
# predicted=1.0644942109860553, 	 expected=1.0764
# predicted=1.077292514323803, 	 expected=1.07164
# predicted=1.0711298889605516, 	 expected=1.0753
# predicted=1.07567655601249, 	 expected=1.0611700000000002
# predicted=1.0613325428347589, 	 expected=1.05321
# predicted=1.053283155878825, 	 expected=1.06359
# predicted=1.0627503155127658, 	 expected=1.0623
# predicted=1.0620217810742356, 	 expected=1.0531
# predicted=1.0537485236552728, 	 expected=1.0411700000000002
# predicted=1.0419144010816739, 	 expected=1.04313
# predicted=1.0434808368941164, 	 expected=1.0401
# predicted=1.0404845735237591, 	 expected=1.0386
# predicted=1.038646823239369, 	 expected=1.0424
# predicted=1.0433413949874784, 	 expected=1.04338
# predicted=1.0429036993725878, 	 expected=1.0456
# predicted=1.0461477994143014, 	 expected=1.0461
# predicted=1.0462718330365501, 	 expected=1.04528
# predicted=1.0452441753268367, 	 expected=1.0414
# predicted=1.0406880278699222, 	 expected=1.04841
# predicted=1.0482289267375249, 	 expected=1.0517
# predicted=1.0525261309542533, 	 expected=1.0452
# predicted=1.0458386291452184, 	 expected=1.0404
# predicted=1.0408790402123675, 	 expected=1.0488
# predicted=1.0491664842079051, 	 expected=1.06005
# predicted=1.060197933055099, 	 expected=1.05284
# predicted=1.0536937917876836, 	 expected=1.0573
# predicted=1.0568369759078502, 	 expected=1.0553299999999999
# predicted=1.0556713200290357, 	 expected=1.05809
# predicted=1.0581502778161012, 	 expected=1.0613
# predicted=1.0614264435921223, 	 expected=1.0600100000000001
# predicted=1.059191243397228, 	 expected=1.0596
# predicted=1.0592504101746871, 	 expected=1.0711
# predicted=1.071809526074658, 	 expected=1.0628600000000001
# predicted=1.0635533187701918, 	 expected=1.0661200000000002
# predicted=1.066442979794822, 	 expected=1.0706200000000001
# predicted=1.0708260130447733, 	 expected=1.07625
# predicted=1.0765049521304906, 	 expected=1.07295
# predicted=1.0737467089139006, 	 expected=1.07473
# predicted=1.0742996195634686, 	 expected=1.06818
# predicted=1.0684846566729829, 	 expected=1.07178
# predicted=1.0717812167604683, 	 expected=1.06925
# predicted=1.0693285071525285, 	 expected=1.07972
# predicted=1.0789807195893668, 	 expected=1.0768799999999998
# predicted=1.0764386472553193, 	 expected=1.07571
# predicted=1.076409651253946, 	 expected=1.07935
# predicted=1.0799252698151052, 	 expected=1.07435
# predicted=1.0747292052702226, 	 expected=1.06795
# predicted=1.0682509547671668, 	 expected=1.0696700000000001
# predicted=1.0698681693765772, 	 expected=1.06568
# predicted=1.0665232498246906, 	 expected=1.06259
# predicted=1.0622147223363476, 	 expected=1.0596
# predicted=1.0599126818924403, 	 expected=1.05771
# predicted=1.0577952155460906, 	 expected=1.05988
# predicted=1.0598430664491165, 	 expected=1.06718
# predicted=1.0664799174614503, 	 expected=1.0608799999999998
# predicted=1.0606232922358199, 	 expected=1.06102
# predicted=1.0615850740863122, 	 expected=1.0536
# predicted=1.0542960498264444, 	 expected=1.0554
# predicted=1.0559244888332004, 	 expected=1.05816
# predicted=1.058528383748414, 	 expected=1.0567600000000001
# predicted=1.056968270880983, 	 expected=1.05861
# predicted=1.0595139976209553, 	 expected=1.0575299999999999
# predicted=1.0571043913030973, 	 expected=1.0547600000000001
# predicted=1.0551447992595706, 	 expected=1.0504
# predicted=1.050436672206492, 	 expected=1.06023
# predicted=1.0602582373521057, 	 expected=1.0581
# predicted=1.057438801316522, 	 expected=1.0566
# predicted=1.0563317630239162, 	 expected=1.05382
# predicted=1.0545165323099082, 	 expected=1.05756
# predicted=1.05816436351686, 	 expected=1.06835
# predicted=1.0687449313694781, 	 expected=1.06524
# predicted=1.06563729908952, 	 expected=1.06035
# predicted=1.0604813558004502, 	 expected=1.07331
# predicted=1.074165195295645, 	 expected=1.0763
# predicted=1.0758441136117805, 	 expected=1.07314
# predicted=1.0735235686058826, 	 expected=1.07384
# predicted=1.0737793385856427, 	 expected=1.08094
# predicted=1.0810658858622677, 	 expected=1.07932
# predicted=1.0785691772847648, 	 expected=1.0782
# predicted=1.0779400609244412, 	 expected=1.08348
# predicted=1.084004567004539, 	 expected=1.0864
# predicted=1.0868844556595574, 	 expected=1.0811
# predicted=1.0815489604047224, 	 expected=1.0765
# predicted=1.0769155242443804, 	 expected=1.0675
# predicted=1.0675144575546454, 	 expected=1.06616
# predicted=1.0669746642346405, 	 expected=1.06684
# predicted=1.066390815086046, 	 expected=1.0671899999999999
# predicted=1.0675127548777033, 	 expected=1.0663
# predicted=1.06630594586592, 	 expected=1.0644
# predicted=1.0645310399869128, 	 expected=1.05817
# predicted=1.0574352807626326, 	 expected=1.05941
# predicted=1.0590789113771362, 	 expected=1.06045
# predicted=1.0610172500186685, 	 expected=1.0663799999999999
# predicted=1.0670834538067062, 	 expected=1.06126
# predicted=1.0617343487190574, 	 expected=1.06139
# predicted=1.061847471244611, 	 expected=1.0640100000000001
# predicted=1.0642157936545806, 	 expected=1.07305
# predicted=1.07388796904796, 	 expected=1.07091
# predicted=1.0704119637271523, 	 expected=1.07158
# predicted=1.071915718221762, 	 expected=1.09043
# predicted=1.0905250823139354, 	 expected=1.08663
# predicted=1.0867796230784914, 	 expected=1.0931899999999999
# predicted=1.0923925215432495, 	 expected=1.0903
# predicted=1.0899972435210643, 	 expected=1.08714
# predicted=1.087655215122322, 	 expected=1.09087
# predicted=1.0915270501688166, 	 expected=1.08965
# predicted=1.0900296812132215, 	 expected=1.09284
# predicted=1.0931147619862895, 	 expected=1.08843
# predicted=1.0884977603687667, 	 expected=1.0983
# predicted=1.0991394412403759, 	 expected=1.10182
# predicted=1.1012881144199227, 	 expected=1.09239
# predicted=1.0924957079459183, 	 expected=1.0873
# predicted=1.0874115409264524, 	 expected=1.08666
# predicted=1.0866574531927367, 	 expected=1.08607
# predicted=1.0853285981907286, 	 expected=1.09285
# predicted=1.0925915963479569, 	 expected=1.0974
# predicted=1.097943307078159, 	 expected=1.10822
# predicted=1.1087999716277146, 	 expected=1.11576
# predicted=1.1160789315350947, 	 expected=1.1102
# predicted=1.110535570575044, 	 expected=1.12037
# predicted=1.1204223714284072, 	 expected=1.1237
# predicted=1.1244442039670965, 	 expected=1.1182
# predicted=1.117758204548231, 	 expected=1.1218
# predicted=1.1221791458985666, 	 expected=1.121
# predicted=1.1210307624054112, 	 expected=1.11658
# predicted=1.1166395445637622, 	 expected=1.1161
# predicted=1.1152199768656579, 	 expected=1.11835
# predicted=1.1179756182116525, 	 expected=1.12453
# predicted=1.1249806694436078, 	 expected=1.1211
# predicted=1.1215698479410807, 	 expected=1.12731
# predicted=1.1277154653622223, 	 expected=1.12539
# predicted=1.1255437394492287, 	 expected=1.12752
# predicted=1.1276621362711714, 	 expected=1.12542
# predicted=1.12626377319585, 	 expected=1.1206399999999999
# predicted=1.120032943008619, 	 expected=1.12001
# predicted=1.1203294366254735, 	 expected=1.1202
# predicted=1.1202681528394507, 	 expected=1.12084
# predicted=1.1208914133470682, 	 expected=1.12173
# predicted=1.1209139486469186, 	 expected=1.11436
# predicted=1.1139878401921737, 	 expected=1.12012
# predicted=1.1207542843582363, 	 expected=1.11485
# predicted=1.1153618871670972, 	 expected=1.1133
# predicted=1.113664293955771, 	 expected=1.11676
# predicted=1.1170367490076305, 	 expected=1.1151
# predicted=1.1153213009627725, 	 expected=1.11962
# predicted=1.1204429758133512, 	 expected=1.1181
# predicted=1.117552324590796, 	 expected=1.1338
# predicted=1.1340910078510755, 	 expected=1.13774
# predicted=1.1377232297242097, 	 expected=1.1441
# predicted=1.144110630443877, 	 expected=1.14175
# predicted=1.1410213754163134, 	 expected=1.13636
# predicted=1.135988821180158, 	 expected=1.13401
# predicted=1.1346360112038298, 	 expected=1.13504
# predicted=1.1356281512868716, 	 expected=1.1422299999999999
# predicted=1.1425008252759825, 	 expected=1.13951
# predicted=1.1398074126325255, 	 expected=1.13994
# predicted=1.1400592478771254, 	 expected=1.1467
# predicted=1.1474431010474293, 	 expected=1.1411
# predicted=1.1403584298730098, 	 expected=1.1397
# predicted=1.1399453613076582, 	 expected=1.1469799999999999
# predicted=1.1468958840326582, 	 expected=1.14781
# predicted=1.1478525598203604, 	 expected=1.1554
# predicted=1.1546155926695751, 	 expected=1.15147
# predicted=1.151185084693783, 	 expected=1.16287
# predicted=1.163381592573745, 	 expected=1.16622
# predicted=1.1666774293065671, 	 expected=1.1640000000000001
# predicted=1.1643208497744104, 	 expected=1.1646
# predicted=1.1648425701715186, 	 expected=1.17324
# predicted=1.173313537540996, 	 expected=1.1674799999999999
# predicted=1.1682357447498912, 	 expected=1.1744299999999999
# predicted=1.1738798640774415, 	 expected=1.18408
# predicted=1.1842544600605065, 	 expected=1.18003
# predicted=1.1799873624651953, 	 expected=1.18556
# predicted=1.1854517901012012, 	 expected=1.18692
# predicted=1.1860724084418037, 	 expected=1.1770100000000001
# predicted=1.1765487699316375, 	 expected=1.1794
# predicted=1.1798710299874144, 	 expected=1.175
# predicted=1.1755656593771282, 	 expected=1.1757
# predicted=1.1759643052119322, 	 expected=1.1771
# predicted=1.1772443585697634, 	 expected=1.18177
# predicted=1.181984075848322, 	 expected=1.1779
# predicted=1.1784948333347693, 	 expected=1.17334
# predicted=1.1726734383359083, 	 expected=1.1766
# predicted=1.1769209705116037, 	 expected=1.17215
# predicted=1.1720692866550457, 	 expected=1.17584
# predicted=1.1758297528678636, 	 expected=1.18146
# predicted=1.1806703559961256, 	 expected=1.17601
# predicted=1.1756791027632036, 	 expected=1.18067
# predicted=1.1812285486523741, 	 expected=1.17991
# predicted=1.1804314982084039, 	 expected=1.19472
# predicted=1.1949564995155169, 	 expected=1.1977
# predicted=1.1978892236797478, 	 expected=1.19721
# predicted=1.1973695683559107, 	 expected=1.18836
# predicted=1.1890821878994486, 	 expected=1.1906
# predicted=1.190012698635358, 	 expected=1.18802
# predicted=1.1883196592818455, 	 expected=1.18918
# predicted=1.189117354548513, 	 expected=1.1909
# predicted=1.190833768185519, 	 expected=1.1916799999999999
# predicted=1.1908054173982365, 	 expected=1.2021700000000002
# predicted=1.2017958586055302, 	 expected=1.20109
# predicted=1.2015737868899234, 	 expected=1.19513
# predicted=1.1954893582146813, 	 expected=1.19661
# predicted=1.1968313675452262, 	 expected=1.1884
# predicted=1.18866606407025, 	 expected=1.1919
# predicted=1.1921043806578693, 	 expected=1.19303
# ...
# predicted=1.1583681987745753, 	 expected=1.1546
# predicted=1.1550173794681957, 	 expected=1.1477
# predicted=1.1478578309504652, 	 expected=1.1514
# predicted=1.1516859363070937, 	 expected=1.15215
# predicted=1.1522065014733103, 	 expected=1.1491200000000001
# predicted=1.149946840294961, 	 expected=1.14897
# predicted=1.1484564187861896, 	 expected=1.1518
# predicted=1.1521332249408704, 	 expected=1.159
# predicted=1.159036747675434, 	 expected=1.1545
# predicted=1.1545654631940814, 	 expected=1.15785
# predicted=1.1570887497149853, 	 expected=1.15731
# predicted=1.1570831594707902, 	 expected=1.15
# predicted=1.1505100148415186, 	 expected=1.1451
# predicted=1.145687745550078, 	 expected=1.1511
# predicted=1.1511900575017546, 	 expected=1.14632
# predicted=1.1466163532148161, 	 expected=1.14697
# predicted=1.1472018128940333, 	 expected=1.13915
# predicted=1.1399492756071223, 	 expected=1.1374
# predicted=1.1368702550510197, 	 expected=1.1388200000000002
# predicted=1.139115646421798, 	 expected=1.1372
# predicted=1.137265672210783, 	 expected=1.13431
# predicted=1.1342332495551792, 	 expected=1.131
# predicted=1.1302531016204078, 	 expected=1.1407
# predicted=1.1405082263385244, 	 expected=1.13975
# predicted=1.1402775407448986, 	 expected=1.1407
# predicted=1.1411358632402342, 	 expected=1.1425
# predicted=1.1426982773122947, 	 expected=1.1425
# predicted=1.142802930619177, 	 expected=1.1364
# predicted=1.136683113414624, 	 expected=1.13143
# predicted=1.1322514418555276, 	 expected=1.12176
# predicted=1.1212719989096354, 	 expected=1.1287
# predicted=1.1291192372809506, 	 expected=1.1309
# predicted=1.1309421789679268, 	 expected=1.1327
# predicted=1.132704852486511, 	 expected=1.14019
# predicted=1.1393278520421843, 	 expected=1.1453
# predicted=1.145015891242523, 	 expected=1.1369
# predicted=1.1373535129016037, 	 expected=1.1383
# predicted=1.1387989911422518, 	 expected=1.14031
# predicted=1.140445998868391, 	 expected=1.1337700000000002
# predicted=1.134153536002421, 	 expected=1.13267
# predicted=1.1329031095091888, 	 expected=1.1288
# predicted=1.1296988925646507, 	 expected=1.13659
# predicted=1.1360347494545475, 	 expected=1.1395
# predicted=1.139861941660664, 	 expected=1.13564
# predicted=1.135619574602606, 	 expected=1.1353
# predicted=1.1351798166967937, 	 expected=1.1341700000000001
# predicted=1.1333938469424758, 	 expected=1.13435
# predicted=1.1341529613650816, 	 expected=1.1375600000000001
# predicted=1.138009673491909, 	 expected=1.13858
# predicted=1.1390804822176008, 	 expected=1.1355
# predicted=1.1357087370858177, 	 expected=1.1315
# predicted=1.1318145015073238, 	 expected=1.13673
# predicted=1.1369316299214078, 	 expected=1.13551
# predicted=1.1361882935219911, 	 expected=1.13012
# predicted=1.1296360402848693, 	 expected=1.1349
# predicted=1.1353352564599908, 	 expected=1.1361
# predicted=1.1361067649826841, 	 expected=1.1374
# predicted=1.1373901529379353, 	 expected=1.1445
# predicted=1.143781924115163, 	 expected=1.1360299999999999
# predicted=1.135685828311087, 	 expected=1.13883
# predicted=1.1392851299763527, 	 expected=1.13785
# predicted=1.1384087276671226, 	 expected=1.1429
# predicted=1.1430540508963922, 	 expected=1.14398
# predicted=1.1442111000364432, 	 expected=1.1465
# predicted=1.1466512396364867, 	 expected=1.1344
# predicted=1.1352378892183794, 	 expected=1.1392
# predicted=1.1386972491300373, 	 expected=1.1396
# predicted=1.1399646984951703, 	 expected=1.14733
# predicted=1.1473066362386068, 	 expected=1.1441
# predicted=1.1439940253230796, 	 expected=1.15416
# predicted=1.1535240419307649, 	 expected=1.1498
# predicted=1.149456076188335, 	 expected=1.14521
# predicted=1.1456807729615126, 	 expected=1.1467
# predicted=1.147153751891105, 	 expected=1.1412
# predicted=1.141290395291441, 	 expected=1.1391
# predicted=1.139379445694379, 	 expected=1.1389
# predicted=1.1391681576610377, 	 expected=1.1363
# predicted=1.137011115971437, 	 expected=1.1364
# predicted=1.135961630432015, 	 expected=1.1359
# predicted=1.13620326057371, 	 expected=1.13801
# predicted=1.138047541894563, 	 expected=1.1303
# predicted=1.1301997655866085, 	 expected=1.13999
# predicted=1.1393026499547048, 	 expected=1.1427
# predicted=1.1424498016152496, 	 expected=1.143
# predicted=1.1434429868570566, 	 expected=1.148
# predicted=1.1485757876415652, 	 expected=1.14428
# predicted=1.1444031646387094, 	 expected=1.14475
# predicted=1.145058514794625, 	 expected=1.1437
# predicted=1.1438269521058595, 	 expected=1.1404
# predicted=1.141167920782818, 	 expected=1.1361
# predicted=1.135673883413196, 	 expected=1.1340000000000001
# predicted=1.134386239241297, 	 expected=1.13202
# predicted=1.132100757186004, 	 expected=1.1275
# predicted=1.1274375691339602, 	 expected=1.1325
# predicted=1.1317362827879778, 	 expected=1.12602
# predicted=1.1257238120577862, 	 expected=1.1294
# predicted=1.1298242784461814, 	 expected=1.12963
# predicted=1.130188552118394, 	 expected=1.1309
# predicted=1.1310040127090741, 	 expected=1.1340000000000001
# predicted=1.1343272421443094, 	 expected=1.1338
# predicted=1.1339365058782203, 	 expected=1.13325
# predicted=1.1340692248193966, 	 expected=1.1345299999999998
# predicted=1.1341219735626338, 	 expected=1.1357
# predicted=1.1361321694199367, 	 expected=1.13879
# predicted=1.1388068529073303, 	 expected=1.1368
# predicted=1.136805914533493, 	 expected=1.137
# predicted=1.1363375935970765, 	 expected=1.13839
# predicted=1.1380505983946103, 	 expected=1.1338
# predicted=1.1342831861291582, 	 expected=1.13071
# predicted=1.1312028476002134, 	 expected=1.1307
# predicted=1.1307781952717364, 	 expected=1.1193
# predicted=1.119630138937756, 	 expected=1.1243
# predicted=1.1244078404569866, 	 expected=1.1252
# predicted=1.1259544616585677, 	 expected=1.1286
# predicted=1.1281592421330369, 	 expected=1.1327
# predicted=1.1330753658058628, 	 expected=1.1302
# predicted=1.1301859280922044, 	 expected=1.13211
# predicted=1.132185807954916, 	 expected=1.1335
# predicted=1.1327418763742294, 	 expected=1.1352
# predicted=1.134957925751867, 	 expected=1.1412
# predicted=1.1417089328369057, 	 expected=1.1371799999999999
# predicted=1.1376815570784502, 	 expected=1.12871
# predicted=1.1289501683974037, 	 expected=1.1314
# predicted=1.1316617440660628, 	 expected=1.1268
# predicted=1.1268882385474919, 	 expected=1.1244
# predicted=1.125134993462294, 	 expected=1.122
# predicted=1.1215408237063127, 	 expected=1.1228
# predicted=1.1232523253909232, 	 expected=1.12125
# predicted=1.12119912545218, 	 expected=1.12039
# predicted=1.1204664379702238, 	 expected=1.1233
# predicted=1.122556134097512, 	 expected=1.122
# predicted=1.1216488911312816, 	 expected=1.1213899999999999
# predicted=1.121918814342037, 	 expected=1.126
# predicted=1.1265998102737724, 	 expected=1.1262
# predicted=1.126261214981561, 	 expected=1.1273
# predicted=1.1276800743143915, 	 expected=1.1251200000000001
# predicted=1.125246754727091, 	 expected=1.12996
# predicted=1.1307573940064855, 	 expected=1.1304
# predicted=1.1299800193346885, 	 expected=1.1279
# predicted=1.1283281937976921, 	 expected=1.1292200000000001
# predicted=1.1291954409195513, 	 expected=1.12315
# predicted=1.1232118305738614, 	 expected=1.12399
# predicted=1.1232841178594861, 	 expected=1.12573
# predicted=1.1254630078694563, 	 expected=1.12257
# predicted=1.1229943767903534, 	 expected=1.1154
# predicted=1.1158937631706838, 	 expected=1.11277
# predicted=1.1128701190246537, 	 expected=1.11499
# predicted=1.115343091610541, 	 expected=1.1185
# predicted=1.118550978715794, 	 expected=1.1213899999999999
# predicted=1.122157298822262, 	 expected=1.1196
# predicted=1.1192294552661364, 	 expected=1.1171
# predicted=1.117503873275547, 	 expected=1.11604
# predicted=1.1160810588778451, 	 expected=1.1198
# predicted=1.119895514496783, 	 expected=1.119
# predicted=1.1182660611793638, 	 expected=1.1192
# predicted=1.118965410861719, 	 expected=1.1212
# predicted=1.1217609221643574, 	 expected=1.12325
# predicted=1.1237640283576102, 	 expected=1.1223
# predicted=1.122381491974271, 	 expected=1.1209
# predicted=1.1211801362740597, 	 expected=1.1205
# predicted=1.1205836959385136, 	 expected=1.1175
# predicted=1.1182937728420816, 	 expected=1.1156
# predicted=1.1152274479261166, 	 expected=1.117
# predicted=1.1174316432138, 	 expected=1.1166
# predicted=1.1165199894172515, 	 expected=1.1154
# predicted=1.1155195731356884, 	 expected=1.11812
# predicted=1.117410569840052, 	 expected=1.12076
# predicted=1.1204613520328768, 	 expected=1.1198
# predicted=1.1202432174628678, 	 expected=1.1161
# predicted=1.1165945960272226, 	 expected=1.11314
# predicted=1.113275261499425, 	 expected=1.113
# predicted=1.113338926176482, 	 expected=1.11612
# predicted=1.1162780663093448, 	 expected=1.12402
# predicted=1.124800165639435, 	 expected=1.12504
# predicted=1.1246104226052593, 	 expected=1.12216
# predicted=1.1225747426034587, 	 expected=1.12753
# predicted=1.1275014462605666, 	 expected=1.13166
# predicted=1.1317228545456208, 	 expected=1.1311799999999999
# predicted=1.130433989492445, 	 expected=1.1327
# predicted=1.1324262612552791, 	 expected=1.12897
# predicted=1.1294680364052465, 	 expected=1.1278
# predicted=1.1282986817883578, 	 expected=1.12065
# predicted=1.120759606475941, 	 expected=1.1216
# predicted=1.1218910096262462, 	 expected=1.1194
# predicted=1.1194317774129428, 	 expected=1.1224
# predicted=1.1231433468990935, 	 expected=1.12914
# predicted=1.128755914006484, 	 expected=1.13715
# predicted=1.1374861813741428, 	 expected=1.1398
# predicted=1.1396992082626385, 	 expected=1.137
# predicted=1.1370982014358013, 	 expected=1.1367
# predicted=1.1359697800517283, 	 expected=1.13685
# predicted=1.1365983537385371, 	 expected=1.1362700000000001
# predicted=1.1367210827271492, 	 expected=1.1287
# predicted=1.1292306223968323, 	 expected=1.1284100000000001
# predicted=1.1284991031724605, 	 expected=1.12804
# predicted=1.128387840576415, 	 expected=1.12827
# predicted=1.1283669738294513, 	 expected=1.12242
# predicted=1.1231047417500843, 	 expected=1.1216
# predicted=1.1211032014109321, 	 expected=1.12086
# predicted=1.121256922116484, 	 expected=1.1250200000000001
# predicted=1.1250196915422934, 	 expected=1.1253
# predicted=1.1254070356427384, 	 expected=1.12691
# predicted=1.1262112373138409, 	 expected=1.1261
# predicted=1.1258165415982493, 	 expected=1.1211200000000001
# predicted=1.1216488088139733, 	 expected=1.12236
# predicted=1.1228028547964, 	 expected=1.12761
# predicted=1.1277161729373681, 	 expected=1.12134
# predicted=1.1216619572002735, 	 expected=1.12085
# predicted=1.1210555560383437, 	 expected=1.1151
# predicted=1.1158894814577176, 	 expected=1.1139
# predicted=1.1135282460023292, 	 expected=1.1146399999999999
# predicted=1.1150349474782193, 	 expected=1.11247
# predicted=1.1124428617007749, 	 expected=1.11443
# predicted=1.1145277651007388, 	 expected=1.1154700000000002
# predicted=1.1147961781012157, 	 expected=1.10758
# predicted=1.1073613621492853, 	 expected=1.1084
# predicted=1.1088265743987618, 	 expected=1.11058
# predicted=1.1109757710310058, 	 expected=1.12022
# predicted=1.1203939736278752, 	 expected=1.12004
# predicted=1.1203706501000599, 	 expected=1.1198299999999999
# predicted=1.1200173823701773, 	 expected=1.1178700000000001
# predicted=1.1186556959620373, 	 expected=1.11953
# predicted=1.1191358305972876, 	 expected=1.12131
# predicted=1.1217750754317632, 	 expected=1.11706
# predicted=1.1170115962725666, 	 expected=1.11376
# predicted=1.113869141079212, 	 expected=1.11067
# predicted=1.1100746499313823, 	 expected=1.10894
# predicted=1.108645480276288, 	 expected=1.1077700000000001
# predicted=1.1081901258865199, 	 expected=1.10994
# predicted=1.1103056997173046, 	 expected=1.1084
# predicted=1.1085039411504856, 	 expected=1.1079
# predicted=1.1082382777758237, 	 expected=1.11598
# predicted=1.1161141577621332, 	 expected=1.10995
# predicted=1.1107084053069198, 	 expected=1.1089200000000001
# predicted=1.1085297399618397, 	 expected=1.1076700000000002
# predicted=1.10816322801921, 	 expected=1.10558
# predicted=1.1056045714711717, 	 expected=1.09961
# predicted=1.099780046017053, 	 expected=1.0966799999999999
# predicted=1.0960136016099615, 	 expected=1.09724
# predicted=1.0969820480641341, 	 expected=1.10344
# predicted=1.1038702049776863, 	 expected=1.10341
# predicted=1.1039269691395048, 	 expected=1.10259
# predicted=1.1027028002051327, 	 expected=1.10463
# predicted=1.1048841418050621, 	 expected=1.10428
# predicted=1.1044627021572886, 	 expected=1.10099
# predicted=1.1017888016538522, 	 expected=1.10624
# predicted=1.1058908227151536, 	 expected=1.10772
# predicted=1.1081765624552953, 	 expected=1.10002
# predicted=1.1000683743002273, 	 expected=1.10719
# predicted=1.1073405974881712, 	 expected=1.10289
# predicted=1.1021901322751733, 	 expected=1.104
# predicted=1.1036556220768095, 	 expected=1.10138
# predicted=1.1018406043963709, 	 expected=1.09925
# predicted=1.0997578087201767, 	 expected=1.10194
# predicted=1.1020253279263426, 	 expected=1.09415
# predicted=1.0945267155733036, 	 expected=1.09196
# predicted=1.0921087819690702, 	 expected=1.0941299999999998
# predicted=1.0948654771776256, 	 expected=1.08976
# predicted=1.089397414765192, 	 expected=1.09311
# predicted=1.093632802387727, 	 expected=1.09586
# predicted=1.0957581327334547, 	 expected=1.09628
# predicted=1.096447085364095, 	 expected=1.0975700000000002
# predicted=1.0968738399010738, 	 expected=1.09703
# predicted=1.0968044652922018, 	 expected=1.09559
# predicted=1.0960771745404447, 	 expected=1.09701
# predicted=1.0974797704302144, 	 expected=1.1004399999999999
# predicted=1.1006350192819558, 	 expected=1.10348
# predicted=1.103863794489149, 	 expected=1.1025399999999999
# predicted=1.1026104728408381, 	 expected=1.10317
# predicted=1.1040095358805235, 	 expected=1.1070799999999998
# predicted=1.1066852445415916, 	 expected=1.11232
# predicted=1.112688940274352, 	 expected=1.11554
# predicted=1.1155092777035296, 	 expected=1.11491
# predicted=1.1149856691459243, 	 expected=1.11243
# predicted=1.1117406152355587, 	 expected=1.1129799999999999
# predicted=1.1127179685963235, 	 expected=1.11035
# predicted=1.1107766312336578, 	 expected=1.10817
# predicted=1.108626880407932, 	 expected=1.10991
# predicted=1.1099581722528586, 	 expected=1.11109
# predicted=1.1114447262602427, 	 expected=1.1149799999999999
# predicted=1.115059356765198, 	 expected=1.11511
# predicted=1.1158347952969823, 	 expected=1.11689
# predicted=1.1164761837090709, 	 expected=1.11269
# predicted=1.1130605922208345, 	 expected=1.10735
# predicted=1.1073400439446572, 	 expected=1.1065399999999999
# predicted=1.1066672225247522, 	 expected=1.10493
# predicted=1.1042375596021243, 	 expected=1.1024100000000001
# predicted=1.102167861687516, 	 expected=1.10325
# predicted=1.103724444225792, 	 expected=1.10084
# predicted=1.1013311358364983, 	 expected=1.10061
# predicted=1.1006963854383938, 	 expected=1.10204
# predicted=1.1023501953100765, 	 expected=1.10506
# predicted=1.105156666812318, 	 expected=1.10713
# predicted=1.10789495050837, 	 expected=1.1077299999999999
# predicted=1.1074410758996762, 	 expected=1.1071799999999998
# predicted=1.1076540746331955, 	 expected=1.1058
# predicted=1.1057918153198762, 	 expected=1.10162
# predicted=1.101735677814838, 	 expected=1.1012
# predicted=1.1005473289865302, 	 expected=1.1020299999999998
# predicted=1.1017451295576588, 	 expected=1.09981
# predicted=1.100282584684046, 	 expected=1.1006799999999999
# predicted=1.101195666660137, 	 expected=1.10239
# predicted=1.1024753254143325, 	 expected=1.10784
# predicted=1.1081639923967823, 	 expected=1.10809
# predicted=1.1081635035402804, 	 expected=1.10763
# predicted=1.1084098658370354, 	 expected=1.1103299999999998
# predicted=1.1099886492783009, 	 expected=1.10578
# predicted=1.106196896926323, 	 expected=1.1063100000000001
# predicted=1.1063338862042607, 	 expected=1.10913
# predicted=1.1092201128134196, 	 expected=1.1128799999999999
# predicted=1.11217440382324, 	 expected=1.11287
# predicted=1.1126087304479464, 	 expected=1.11295
# predicted=1.1133657452207728, 	 expected=1.1143299999999998
# predicted=1.1148086292815502, 	 expected=1.1149799999999999
# predicted=1.1150141079806246, 	 expected=1.11123
# predicted=1.111587227255581, 	 expected=1.1119700000000001
# predicted=1.1120716413663787, 	 expected=1.10822
# predicted=1.1089768580635047, 	 expected=1.1088200000000001
# predicted=1.1085211672513717, 	 expected=1.10925
# predicted=1.109637910508452, 	 expected=1.10953

# %%
# Plot predictions against known values
#expected.plot(legend=True, figsize=(12,6))
#pd.DataFrame(predictions).plot(legend=True)
#plt.autoscale(axis = 'x', tight=True)

# %%
from sklearn.metrics import mean_squared_error

error = mean_squared_error(test, predictions)
print(f'SARIMAX(1,0,0) MSE Error {error}')
# Out:
# SARIMAX(1,0,0) MSE Error 3.488700192443124e-05

# %%
from statsmodels.tools.eval_measures import rmse

error = rmse(test, predictions)
print(f'SARIMAX(1,0,0) RMSE Error: {error:11.10}')
# Out:
# SARIMAX(1,0,0) RMSE Error: 0.005906521982

# %% [markdown]
# #### Retrain Sarimax model

# %%
model = SARIMAX(eurusd['Open'], order=(1,0,0), seasonal_order=(1,1,1,12), enforce_invinsibility=False)
result2 = model.fit()
fcast = result2.predict(len(eurusd), len(eurusd)+365*5, dynamic=True, typ='levels').rename('SARIMAX(1,0,0)Forecast')

# %%
# Plot predictions against known values

ax = eurusd['Open'].plot(legend=True, figsize=(12,6))
fcast.plot(legend=True)
ax.autoscale(axis='x', tight=True)
