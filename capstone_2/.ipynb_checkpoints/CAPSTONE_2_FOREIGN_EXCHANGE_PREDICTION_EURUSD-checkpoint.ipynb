# %% [markdown]
# #### Capstone 2 Arima Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib  as mpl 
# %matplotlib inline

# Load Specific forecasting tools
from statsmodels.tsa.arima_model import ARIMA,ARIMAResults, ARIMA, ARIMAResults
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima import auto_arima

import itertools
import statsmodels.api as sm
plt.style.use('fivethirtyeight')
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller



# Ignore harmless warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#get data
eurusd = pd.read_csv(r'eurusd.csv', index_col=0, parse_dates=True, skipinitialspace=True)

# %%
eurusd.head()
# Out:
#               Open    High     Low   close  Change  Volume
# date
# 2000-01-03  1.0085  1.0280  1.0055  1.0256  0.0168       0
# 2000-01-04  1.0255  1.0340  1.0217  1.0301  0.0045       0
# 2000-01-05  1.0304  1.0400  1.0289  1.0315  0.0014       0
# 2000-01-06  1.0320  1.0413  1.0283  1.0315  0.0000       0
# 2000-01-07  1.0317  1.0333  1.0263  1.0296 -0.0019       0

# %%
eurusd.tail()
# Out:
#                Open     High      Low    close   Change  Volume
# date
# 2019-12-20  1.11197  1.11246  1.10661  1.10748 -0.00448  119919
# 2019-12-23  1.10822  1.10954  1.10697  1.10884  0.00136  109071
# 2019-12-24  1.10882  1.10937  1.10693  1.10877 -0.00007  102337
# 2019-12-26  1.10925  1.11115  1.10819  1.10952  0.00075   59499
# 2019-12-27  1.10953  1.11878  1.10939  1.11726  0.00774  157620

# %%
eurusd.index
# Out:
# DatetimeIndex(['2000-01-03', '2000-01-04', '2000-01-05', '2000-01-06',
#                '2000-01-07', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14',
#                ...
#                '2019-12-13', '2019-12-16', '2019-12-17', '2019-12-18',
#                '2019-12-19', '2019-12-20', '2019-12-23', '2019-12-24',
#                '2019-12-26', '2019-12-27'],
#               dtype='datetime64[ns]', name='date', length=5187, freq=None)

# %%
eurusd.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# close     float64
# Change    float64
# Volume      int64
# dtype: object

# %%
eurusdclose = eurusd.close

# %%
eurusdclose.describe()
# Out:
# count    5187.000000
# mean        1.209322
# std         0.166613
# min         0.827100
# 25%         1.110505
# 50%         1.225900
# 75%         1.331400
# max         1.599000
# Name: close, dtype: float64

# %%
# Check for missing data
print(eurusd.isnull().sum())
# Out:
# Open      0
# High      0
# Low       0
# close     0
# Change    0
# Volume    0
# dtype: int64

# %% [markdown]
# There are no missing values in the data set

# %%
eurusdclose.hist()

# %%
eurusd['close'].plot(ylim=[0,1.75],figsize = (12,5)).autoscale(axis='x', tight=True)
plt.title('Exchange Rate Chart', size=20)
plt.xlabel('Years', size=17)
plt.ylabel('Exchange Rate', size=17)
plt.autoscale(enable=True, axis='x', tight=True)
plt.tick_params(labelsize=14)

# %%
# Carry out Decomposition

seasonal = seasonal_decompose(eurusd.close, model='multiplicative', freq=52)
seasonal.plot()
mpl.rcParams['figure.figsize'] = 12,6

# %% [markdown]
# STATIONARITY

# %%
eurusd['12-month-SMA(close)'] = eurusd['close'].rolling(window=12).mean()
eurusd['12-month-std(close)'] = eurusd['close'].rolling(window=12).std()
eurusd[['close', '12-month-SMA(close)', '12-month-std(close)']].plot()
plt.ylim(0, 2)
plt.xlabel('Years', size=17)
plt.ylabel('Exchange Rate', size=17)
plt.autoscale(enable=True, axis='x', tight=True)#plt.axis('tight'
plt.tick_params(labelsize=14)
mpl.rcParams['figure.figsize'] = 12,6

# %% [markdown]
# From the chart above, it is clear that the Standard deviation is stationary, while the mean is not

# %%
#eurusd['shift'] =  eurusd['close'].shift(1)
#eurusd.head()

# %%
#eurusd['d1close'] = eurusd['close']  -  eurusd['close'].shift(1)
#eurusd[['d1close', 'close']].head()

# %%
#eurusd['d1close'].plot(title='First order difference').autoscale(axis='x', tight='True')

# %%
eurusd['d1close'] = eurusd['close'].diff()
eurusd['d1close'].plot(title='First order difference').autoscale(axis='x', tight='True')

# %%
eurusd['12-month-SMA(close)'] = eurusd['d1close'].rolling(window=12).mean()
eurusd['12-month-std(close)'] = eurusd['d1close'].rolling(window=12).std()
eurusd[['d1close', '12-month-SMA(close)', '12-month-std(close)']].plot()
plt.xlabel('Years', size=17)
plt.ylabel('Exchange Rate', size=17)
plt.autoscale(enable=True, axis='x', tight=True)#plt.axis('tight'
plt.tick_params(labelsize=14)
mpl.rcParams['figure.figsize'] = 12,6

# %%
print('Augmented Dickey-Fuller Test on EURUSD Exchange Rate Data')
dftest = adfuller(eurusd['close'], autolag='AIC')
dftest
# Out:
# Augmented Dickey-Fuller Test on EURUSD Exchange Rate Data
# (-1.7338439209888068,
#  0.4137648010102527,
#  0,
#  5186,
#  {'1%': -3.4316115772743645,
#   '5%': -2.8620974851364487,
#   '10%': -2.567066749257732},
#  -35987.182541465096)

# %% [markdown]
# Hypothesis Testing:
#
# The Null hypothesis of this project states that the time series data of eurysd is non-stationary. Using the Dickey fuller test, I will determine below whether or not this is true.

# %%
#stepwise_fit = auto_arima(eurusd['close'], start_P = 1, start_q = 1, max_p = 3, max_q = 3, m=12, start_p = 0, seasonal =True
                          , d=None, D=1, trace=True, 
                           error_action='ignore', # We don't want to know if an order does not work
                           surpress_warnings=True, #We don't want convergence warnings
                           stepwise=True) #Set to stepwise
#stepwise_fit.summary()
# Out:
#   File "<ipython-input-20-a2cce5664cf4>", line 2
#     ("d=None,", "D=1,", "trace=True,")
#     ^
# IndentationError: unexpected indent

# %%
#First order differencing

#import statsmodels.tsa.statespace.tools 
##import diff
#eurusd['d1'] = diff(eurusd['close'], k_diff = 1)

# %%
print('Augmented Dickey-Fuller Test on EURUSD Exchange Rate Data')
dfout = pd.Series(dftest[0:4], index = ['ADF Test Statistic', 'p-value', '# lags used', '# observations'])

for key, val in dftest[4].items():
    dfout[f'critical value({key})']=val
    print(dfout)
# Out:
# Augmented Dickey-Fuller Test on EURUSD Exchange Rate Data
# ADF Test Statistic      -1.733844
# p-value                  0.413765
# # lags used              0.000000
# # observations        5186.000000
# critical value(1%)      -3.431612
# dtype: float64
# ADF Test Statistic      -1.733844
# p-value                  0.413765
# # lags used              0.000000
# # observations        5186.000000
# critical value(1%)      -3.431612
# critical value(5%)      -2.862097
# dtype: float64
# ADF Test Statistic       -1.733844
# p-value                   0.413765
# # lags used               0.000000
# # observations         5186.000000
# critical value(1%)       -3.431612
# critical value(5%)       -2.862097
# critical value(10%)      -2.567067
# dtype: float64

# %% [markdown]
# The P-value above is greater than 5% using the dickey fuller test, hence we accept the null-hypothesis to be true, that our time series data for eurusd is non-stationary

# %% [markdown]
# MACHINE LEARNING

# %% [markdown]
# ARIMA MODEL

# %%
eurusd.shape
# Out:
# (5187, 9)

# %%
train, test = eurusd.close[:4000], eurusd.close[4000:]

# %%
from statsmodels.tsa.arima_model import ARIMA,ARIMAResults, ARIMA, ARIMAResults

# %%
model = ARIMA(train, order = (1,0,0))
results = model.fit(disp=0)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 4000
# Model:                     ARMA(1, 0)   Log Likelihood               13713.099
# Method:                       css-mle   S.D. of innovations              0.008
# Date:                Sun, 05 Jan 2020   AIC                         -27420.198
# Time:                        19:21:17   BIC                         -27401.316
# Sample:                             0   HQIC                        -27413.505
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           1.1801      0.105     11.257      0.000       0.975       1.386
# ar.L1.close     0.9990      0.001   1648.874      0.000       0.998       1.000
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0010           +0.0000j            1.0010            0.0000
# -----------------------------------------------------------------------------
# """

# %%
# Obtain predicted values

start = len(train)
end = len(train) + len(test)-1
predictions = results.predict(start=start, end = end, dynamic = False).rename('ARIMA(1,0,0) Predictions')
#, typ='levels'

# %%
predictions
# Out:
# 4000    1.127462
# 4001    1.127514
# 4002    1.127565
# 4003    1.127617
# 4004    1.127669
#           ...
# 5182    1.163663
# 5183    1.163679
# 5184    1.163695
# 5185    1.163711
# 5186    1.163727
# Name: ARIMA(1,0,0) Predictions, Length: 1187, dtype: float64

# %%
# Compare predictions to expected values
forecast_errors = [expected[i]-predictions[i] for i in range(len(expected))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-1134732d0c35> in <module>
#       1 # Compare predictions to expected values
# ----> 2 forecast_errors = [expected[i]-predictions[i] for i in range(len(expected))]
#
# <ipython-input-29-1134732d0c35> in <listcomp>(.0)
#       1 # Compare predictions to expected values
# ----> 2 forecast_errors = [expected[i]-predictions[i] for i in range(len(expected))]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
# Print out predictions, expected and forecast error
for i in range(len(predictions)):
    print(f"predicted={predictions[i]}, \t expected={test[i]}, \t forecast_errors={forecast_errors[i]}")
# Out:
# predicted=1.2195676644597806, 	 expected=1.4376, 	 forecast_errors=0.2180323355402194
# predicted=1.02575570387118, 	 expected=1.4509100000000001, 	 forecast_errors=0.42515429612882016
# predicted=1.0302520915813569, 	 expected=1.4367299999999998, 	 forecast_errors=0.40647790841864295
# predicted=1.0316509677578565, 	 expected=1.43309, 	 forecast_errors=0.4014390322421435
# predicted=1.0316509677578565, 	 expected=1.43967, 	 forecast_errors=0.40801903224214353
# predicted=1.0297524929468929, 	 expected=1.4249100000000001, 	 forecast_errors=0.39515750705310726
# predicted=1.0255558644173943, 	 expected=1.42018, 	 forecast_errors=0.3946241355826057
# predicted=1.0332496833881415, 	 expected=1.4322, 	 forecast_errors=0.3989503166118584
# predicted=1.0309515296696066, 	 expected=1.4091200000000002, 	 forecast_errors=0.3781684703303936
# predicted=1.0253560249636084, 	 expected=1.4279700000000002, 	 forecast_errors=0.40261397503639174
# predicted=1.0143648550053979, 	 expected=1.4176799999999998, 	 forecast_errors=0.40331514499460197
# predicted=1.0113672631986133, 	 expected=1.43743, 	 forecast_errors=0.42606273680138673
# predicted=1.0136654169171482, 	 expected=1.41764, 	 forecast_errors=0.40397458308285183
# predicted=1.01266621964822, 	 expected=1.42392, 	 forecast_errors=0.4112537803517802
# predicted=1.0176622059928613, 	 expected=1.4245299999999999, 	 forecast_errors=0.4068677940071386
# predicted=1.008669430572507, 	 expected=1.44428, 	 forecast_errors=0.435610569427493
# predicted=1.0071706346691147, 	 expected=1.44061, 	 forecast_errors=0.43343936533088523
# predicted=1.0010755313286523, 	 expected=1.4424700000000001, 	 forecast_errors=0.4413944686713478
# predicted=1.0015751299631166, 	 expected=1.43317, 	 forecast_errors=0.43159487003688346
# predicted=0.9883858259329907, 	 expected=1.43943, 	 forecast_errors=0.45104417406700925
# predicted=0.9770947968743748, 	 expected=1.4356799999999998, 	 forecast_errors=0.458585203125625
# predicted=0.9690012989960561, 	 expected=1.44401, 	 forecast_errors=0.4750087010039439
# predicted=0.9722986499835192, 	 expected=1.4413200000000002, 	 forecast_errors=0.46902135001648093
# predicted=0.9766951179668035, 	 expected=1.43777, 	 forecast_errors=0.46107488203319646
# predicted=0.9901843810170616, 	 expected=1.4484299999999999, 	 forecast_errors=0.45824561898293825
# predicted=0.9822906226728016, 	 expected=1.45095, 	 forecast_errors=0.4686593773271983
# predicted=0.9801923084080524, 	 expected=1.44407, 	 forecast_errors=0.4638776915919476
# predicted=0.9861875919413488, 	 expected=1.4369100000000001, 	 forecast_errors=0.4507224080586514
# predicted=0.9928821137234409, 	 expected=1.42582, 	 forecast_errors=0.43293788627655916
# predicted=0.9852882144795864, 	 expected=1.41913, 	 forecast_errors=0.43384178552041364
# predicted=0.9867870103829788, 	 expected=1.40963, 	 forecast_errors=0.42284298961702116
# predicted=0.9801923084080524, 	 expected=1.39967, 	 forecast_errors=0.4194776915919476
# predicted=0.9811916055967076, 	 expected=1.4096899999999999, 	 forecast_errors=0.4284983944032923
# predicted=0.986687090656086, 	 expected=1.38802, 	 forecast_errors=0.4013329093439141
# predicted=0.9881858865594781, 	 expected=1.3654700000000002, 	 forecast_errors=0.37728411344052204
# predicted=0.9849884552989079, 	 expected=1.3677700000000002, 	 forecast_errors=0.38278154470109227
# predicted=0.9873866286640626, 	 expected=1.36773, 	 forecast_errors=0.3803433713359373
# predicted=1.0038732836816515, 	 expected=1.37531, 	 forecast_errors=0.3714367163183485
# predicted=1.0035735245009731, 	 expected=1.38751, 	 forecast_errors=0.3839364754990269
# predicted=0.9925824544624894, 	 expected=1.3798700000000002, 	 forecast_errors=0.38728754553751077
# predicted=0.9745968037020543, 	 expected=1.36857, 	 forecast_errors=0.3939731962979458
# predicted=0.9715993118149964, 	 expected=1.36995, 	 forecast_errors=0.39835068818500363
# predicted=0.9647048506593916, 	 expected=1.3571, 	 forecast_errors=0.3923951493406084
# predicted=0.9733978668990673, 	 expected=1.3463100000000001, 	 forecast_errors=0.37291213310093285
# predicted=0.9653042691010216, 	 expected=1.34988, 	 forecast_errors=0.38457573089897834
# predicted=0.9584098079454169, 	 expected=1.35325, 	 forecast_errors=0.3948401920545832
# predicted=0.9588094868529882, 	 expected=1.3585200000000002, 	 forecast_errors=0.399710513147012
# predicted=0.9583098882185239, 	 expected=1.3542100000000001, 	 forecast_errors=0.3959001117814762
# predicted=0.9609078011177374, 	 expected=1.35962, 	 forecast_errors=0.3987121988822626
# predicted=0.9669030846510338, 	 expected=1.33848, 	 forecast_errors=0.3715769153489661
# predicted=0.963405794290058, 	 expected=1.31748, 	 forecast_errors=0.35407420570994197
# predicted=0.9635057140169508, 	 expected=1.33489, 	 forecast_errors=0.37138428598304907
# predicted=0.9683018609078063, 	 expected=1.33474, 	 forecast_errors=0.3664381390921937
# predicted=0.9670029044581996, 	 expected=1.3436700000000001, 	 forecast_errors=0.37666709554180056
# predicted=0.9692011384498419, 	 expected=1.3375299999999999, 	 forecast_errors=0.368328861550158
# predicted=0.9719988908028409, 	 expected=1.3640700000000001, 	 forecast_errors=0.39207110919715926
# predicted=0.9730981077183889, 	 expected=1.3638700000000001, 	 forecast_errors=0.39077189228161124
# predicted=0.9627063562018083, 	 expected=1.37911, 	 forecast_errors=0.4164036437981917
# predicted=0.9608078813908446, 	 expected=1.37764, 	 forecast_errors=0.41683211860915537
# predicted=0.9716991316221624, 	 expected=1.3879700000000001, 	 forecast_errors=0.4162708683778378
# predicted=0.9754960812440896, 	 expected=1.37364, 	 forecast_errors=0.3981439187559104
# predicted=0.9673026636388782, 	 expected=1.3751200000000001, 	 forecast_errors=0.40781733636112194
# predicted=0.9605081222101661, 	 expected=1.37589, 	 forecast_errors=0.41538187778983393
# predicted=0.9514155269826461, 	 expected=1.3779299999999999, 	 forecast_errors=0.4265144730173538
# predicted=0.9617071589328801, 	 expected=1.38927, 	 forecast_errors=0.42756284106711995
# predicted=0.9556120555924179, 	 expected=1.39283, 	 forecast_errors=0.4372179444075821
# predicted=0.9557120752390376, 	 expected=1.39062, 	 forecast_errors=0.4349079247609624
# predicted=0.959409105134072, 	 expected=1.3905, 	 forecast_errors=0.4310908948659281
# predicted=0.9625066166677495, 	 expected=1.41876, 	 forecast_errors=0.4562533833322505
# predicted=0.9585098275920365, 	 expected=1.4146, 	 forecast_errors=0.45609017240796357
# predicted=0.9547127780503823, 	 expected=1.3856899999999999, 	 forecast_errors=0.4309772219496175
# predicted=0.9625066166677495, 	 expected=1.37011, 	 forecast_errors=0.40760338333225044
# predicted=0.9592092656802864, 	 expected=1.37459, 	 forecast_errors=0.41538073431971356
# predicted=0.9589095064996079, 	 expected=1.38222, 	 forecast_errors=0.42331049350039207
# predicted=0.9530141426932044, 	 expected=1.37907, 	 forecast_errors=0.4260558573067956
# predicted=0.962206857487071, 	 expected=1.3774600000000001, 	 forecast_errors=0.4152531425129291
# predicted=0.9525145440587404, 	 expected=1.38326, 	 forecast_errors=0.43074545594125957
# predicted=0.9455201631762427, 	 expected=1.35412, 	 forecast_errors=0.40859983682375733
# predicted=0.9403243373778158, 	 expected=1.36093, 	 forecast_errors=0.42060566262218413
# predicted=0.9385257822937451, 	 expected=1.37467, 	 forecast_errors=0.436144217706255
# predicted=0.9380261836592809, 	 expected=1.36323, 	 forecast_errors=0.425203816340719
# predicted=0.9380261836592809, 	 expected=1.35386, 	 forecast_errors=0.41583381634071914
# predicted=0.9205402314530368, 	 expected=1.34625, 	 forecast_errors=0.4257097685469632
# predicted=0.9232380640791429, 	 expected=1.3457, 	 forecast_errors=0.422461935920857
# predicted=0.9095490614948263, 	 expected=1.35227, 	 forecast_errors=0.4427209385051738
# predicted=0.9115474560326826, 	 expected=1.34883, 	 forecast_errors=0.43728254396731736
# predicted=0.9156442647550154, 	 expected=1.3504, 	 forecast_errors=0.4347557352449847
# predicted=0.9095490614948263, 	 expected=1.33408, 	 forecast_errors=0.42453093850517365
# predicted=0.894361263007117, 	 expected=1.33455, 	 forecast_errors=0.44018873699288286
# predicted=0.88986487529694, 	 expected=1.3236700000000001, 	 forecast_errors=0.4338051247030601
# predicted=0.8973588548139018, 	 expected=1.33188, 	 forecast_errors=0.4345211451860982
# predicted=0.8976587139143072, 	 expected=1.33138, 	 forecast_errors=0.4337212860856928
# predicted=0.9075507668766967, 	 expected=1.34449, 	 forecast_errors=0.4369392331233033
# predicted=0.9067513091418271, 	 expected=1.34607, 	 forecast_errors=0.439318690858173
# predicted=0.9016555029900202, 	 expected=1.33913, 	 forecast_errors=0.43747449700997976
# predicted=0.9182420777345017, 	 expected=1.34002, 	 forecast_errors=0.42177792226549826
# predicted=0.9114475363057899, 	 expected=1.3400299999999998, 	 forecast_errors=0.42858246369420994
# predicted=0.9005562860744721, 	 expected=1.34107, 	 forecast_errors=0.44051371392552785
# predicted=0.8950607010953668, 	 expected=1.33395, 	 forecast_errors=0.43888929890463313
# predicted=0.8947609419146884, 	 expected=1.33843, 	 forecast_errors=0.44366905808531165
# predicted=0.897258935087009, 	 expected=1.31864, 	 forecast_errors=0.421381064912991
# predicted=0.9030542792467928, 	 expected=1.30356, 	 forecast_errors=0.40050572075320723
# predicted=0.90685122886872, 	 expected=1.29819, 	 forecast_errors=0.3913387711312799
# predicted=0.904053476515721, 	 expected=1.3014700000000001, 	 forecast_errors=0.39741652348427914
# predicted=0.9115474560326827, 	 expected=1.30443, 	 forecast_errors=0.39288254396731725
# predicted=0.9309319829696173, 	 expected=1.2998, 	 forecast_errors=0.36886801703038274
# predicted=0.926635434713226, 	 expected=1.30815, 	 forecast_errors=0.38151456528677397
# predicted=0.9303323646885335, 	 expected=1.3046, 	 forecast_errors=0.37426763531146645
# predicted=0.9375265850248168, 	 expected=1.30494, 	 forecast_errors=0.3674134149751832
# predicted=0.931131822423403, 	 expected=1.3044799999999999, 	 forecast_errors=0.3733481775765969
# predicted=0.9460197618107067, 	 expected=1.30574, 	 forecast_errors=0.3597202381892932
# predicted=0.9479183365413973, 	 expected=1.30693, 	 forecast_errors=0.3590116634586026
# predicted=0.954413018869704, 	 expected=1.2939399999999999, 	 forecast_errors=0.3395269811302959
# predicted=0.9615073194790944, 	 expected=1.296, 	 forecast_errors=0.33449268052090564
# predicted=0.9561117541466089, 	 expected=1.2957299999999998, 	 forecast_errors=0.33961824585339095
# predicted=0.953214082066717, 	 expected=1.3048899999999999, 	 forecast_errors=0.3516759179332829
# predicted=0.9534138216007757, 	 expected=1.2942, 	 forecast_errors=0.3407861783992243
# predicted=0.9596089445878576, 	 expected=1.27875, 	 forecast_errors=0.31914105541214244
# predicted=0.9579103092306798, 	 expected=1.27149, 	 forecast_errors=0.31357969076932024
# predicted=0.9546129582432165, 	 expected=1.2763799999999998, 	 forecast_errors=0.3217670417567834
# predicted=0.9647048506593916, 	 expected=1.27767, 	 forecast_errors=0.3129651493406085
# predicted=0.9566113527810729, 	 expected=1.27053, 	 forecast_errors=0.31391864721892704
# predicted=0.9547127780503823, 	 expected=1.28134, 	 forecast_errors=0.3266272219496176
# predicted=0.9445210658270413, 	 expected=1.2678200000000002, 	 forecast_errors=0.32329893417295885
# predicted=0.93562821013358, 	 expected=1.2665600000000001, 	 forecast_errors=0.33093178986642013
# predicted=0.9353283510331747, 	 expected=1.27349, 	 forecast_errors=0.3381616489668253
# predicted=0.9367273271294011, 	 expected=1.2863, 	 forecast_errors=0.3495726728705989
# predicted=0.9454203433690767, 	 expected=1.2968, 	 forecast_errors=0.3513796566309233
# predicted=0.9412236149198512, 	 expected=1.29291, 	 forecast_errors=0.3516863850801488
# predicted=0.9517152861633247, 	 expected=1.30122, 	 forecast_errors=0.34950471383667536
# predicted=0.9527143835125259, 	 expected=1.30351, 	 forecast_errors=0.35079561648747404
# predicted=0.9502163903402053, 	 expected=1.31051, 	 forecast_errors=0.36029360965979473
# predicted=0.9515153467898121, 	 expected=1.31079, 	 forecast_errors=0.3592746532101878
# predicted=0.9529143228860385, 	 expected=1.3217299999999998, 	 forecast_errors=0.36881567711396135
# predicted=0.9509158284284551, 	 expected=1.31421, 	 forecast_errors=0.363294171571545
# predicted=0.9483179155292418, 	 expected=1.3083, 	 forecast_errors=0.3599820844707582
# predicted=0.9551125568776806, 	 expected=1.31595, 	 forecast_errors=0.36083744312231936
# predicted=0.95261456370536, 	 expected=1.3142399999999999, 	 forecast_errors=0.36162543629463983
# predicted=0.9425225713694579, 	 expected=1.3158299999999998, 	 forecast_errors=0.3733074286305419
# predicted=0.9373267455710311, 	 expected=1.3129, 	 forecast_errors=0.37557325442896883
# predicted=0.9382260231130665, 	 expected=1.32594, 	 forecast_errors=0.38771397688693343
# predicted=0.936327548302103, 	 expected=1.32597, 	 forecast_errors=0.38964245169789713
# predicted=0.9253363783438924, 	 expected=1.32847, 	 forecast_errors=0.40313362165610767
# predicted=0.9246370401753695, 	 expected=1.31969, 	 forecast_errors=0.3950529598246305
# predicted=0.9332300367684253, 	 expected=1.3185799999999999, 	 forecast_errors=0.38534996323157455
# predicted=0.9371270060369724, 	 expected=1.31329, 	 forecast_errors=0.37616299396302766
# predicted=0.9334299761419378, 	 expected=1.3065200000000001, 	 forecast_errors=0.37309002385806234
# predicted=0.9384259624865791, 	 expected=1.31294, 	 forecast_errors=0.37451403751342094
# predicted=0.9431221896505417, 	 expected=1.31407, 	 forecast_errors=0.37094781034945834
# predicted=0.9316314210578671, 	 expected=1.32412, 	 forecast_errors=0.39248857894213285
# predicted=0.9233379838060358, 	 expected=1.3233, 	 forecast_errors=0.3999620161939641
# predicted=0.9262357558056546, 	 expected=1.32481, 	 forecast_errors=0.3985742441943454
# predicted=0.9143452083856818, 	 expected=1.3371, 	 forecast_errors=0.42275479161431817
# predicted=0.9137457899440518, 	 expected=1.34453, 	 forecast_errors=0.43078421005594825
# predicted=0.9067513091418271, 	 expected=1.33968, 	 forecast_errors=0.43292869085817287
# predicted=0.9081502852380536, 	 expected=1.34569, 	 forecast_errors=0.4375397147619464
# predicted=0.9071509880493984, 	 expected=1.33237, 	 forecast_errors=0.42521901195060163
# predicted=0.902255021351377, 	 expected=1.3310899999999999, 	 forecast_errors=0.42883497864862286
# predicted=0.9008560452551506, 	 expected=1.3196299999999999, 	 forecast_errors=0.41877395474484924
# predicted=0.908549864225898, 	 expected=1.32159, 	 forecast_errors=0.41304013577410204
# predicted=0.9036538975278765, 	 expected=1.3111700000000002, 	 forecast_errors=0.40751610247212366
# predicted=0.9058520315997918, 	 expected=1.31483, 	 forecast_errors=0.40897796840020817
# predicted=0.9132460913898606, 	 expected=1.32736, 	 forecast_errors=0.4141139086101395
# predicted=0.9160438437428597, 	 expected=1.31223, 	 forecast_errors=0.39618615625714027
# predicted=0.916443522650431, 	 expected=1.31545, 	 forecast_errors=0.39900647734956896
# predicted=0.9065514696880415, 	 expected=1.30826, 	 forecast_errors=0.4017085303119585
# predicted=0.9018552425240788, 	 expected=1.3031700000000002, 	 forecast_errors=0.4013147574759214
# predicted=0.8965594969987591, 	 expected=1.3079100000000001, 	 forecast_errors=0.411350503001241
# predicted=0.9018552425240789, 	 expected=1.31703, 	 forecast_errors=0.41517475747592103
# predicted=0.9026547002589483, 	 expected=1.32372, 	 forecast_errors=0.42106529974105167
# predicted=0.902255021351377, 	 expected=1.3224, 	 forecast_errors=0.420144978648623
# predicted=0.8999567677131153, 	 expected=1.3215299999999999, 	 forecast_errors=0.4215732322868846
# predicted=0.8923628684692606, 	 expected=1.31998, 	 forecast_errors=0.4276171315307393
# predicted=0.8940615038264387, 	 expected=1.3268799999999998, 	 forecast_errors=0.43281849617356116
# predicted=0.8879665004057032, 	 expected=1.33569, 	 forecast_errors=0.4477234995942968
# predicted=0.8998568479862223, 	 expected=1.33141, 	 forecast_errors=0.43155315201377764
# predicted=0.8974587745407946, 	 expected=1.33161, 	 forecast_errors=0.43415122545920537
# predicted=0.8897649555700472, 	 expected=1.33013, 	 forecast_errors=0.44036504442995283
# predicted=0.8703805285528394, 	 expected=1.33399, 	 forecast_errors=0.4636094714471606
# predicted=0.8714796455486605, 	 expected=1.33195, 	 forecast_errors=0.46047035445133944
# predicted=0.8668833381115907, 	 expected=1.32323, 	 forecast_errors=0.4563466618884092
# predicted=0.8576908231571778, 	 expected=1.3141200000000002, 	 forecast_errors=0.45642917684282236
# predicted=0.8639856660316988, 	 expected=1.30649, 	 forecast_errors=0.44250433396830113
# predicted=0.8594893782412486, 	 expected=1.31049, 	 forecast_errors=0.45100062175875133
# predicted=0.8645851843930557, 	 expected=1.30806, 	 forecast_errors=0.44347481560694435
# predicted=0.8540936130693093, 	 expected=1.31082, 	 forecast_errors=0.4567263869306908
# predicted=0.8536940340814648, 	 expected=1.3185799999999999, 	 forecast_errors=0.46488596591853504
# predicted=0.8507962620818461, 	 expected=1.3075299999999999, 	 forecast_errors=0.45673373791815375
# predicted=0.8490976267246682, 	 expected=1.31402, 	 forecast_errors=0.4649223732753318
# predicted=0.8597891374219271, 	 expected=1.3125799999999999, 	 forecast_errors=0.4527908625780728
# predicted=0.8766755712668143, 	 expected=1.31219, 	 forecast_errors=0.4355144287331857
# predicted=0.874577157082338, 	 expected=1.31365, 	 forecast_errors=0.439072842917662
# predicted=0.8832701733220137, 	 expected=1.3216700000000001, 	 forecast_errors=0.4383998266779864
# predicted=0.8833700930489066, 	 expected=1.3155700000000001, 	 forecast_errors=0.43219990695109356
# predicted=0.8787737856118366, 	 expected=1.31958, 	 forecast_errors=0.44080621438816336
# predicted=0.8833700930489066, 	 expected=1.32161, 	 forecast_errors=0.4382399069510934
# predicted=0.8767754909937071, 	 expected=1.32226, 	 forecast_errors=0.4454845090062929
# predicted=0.8757761938050519, 	 expected=1.32503, 	 forecast_errors=0.44925380619494804
# predicted=0.8750767557168022, 	 expected=1.32384, 	 forecast_errors=0.4487632442831977
# predicted=0.8692814115570185, 	 expected=1.3236299999999999, 	 forecast_errors=0.4543485884429813
# predicted=0.8685819734687685, 	 expected=1.31577, 	 forecast_errors=0.4471880265312316
# predicted=0.8685819734687686, 	 expected=1.31516, 	 forecast_errors=0.44657802653123146
# predicted=0.8719792441831247, 	 expected=1.30692, 	 forecast_errors=0.4349407558168754
# predicted=0.8684821536616028, 	 expected=1.3049899999999999, 	 forecast_errors=0.4365078463383971
# predicted=0.863286227943449, 	 expected=1.30049, 	 forecast_errors=0.4372037720565509
# predicted=0.8552926497920231, 	 expected=1.2928, 	 forecast_errors=0.4375073502079768
# predicted=0.8497971647326448, 	 expected=1.29351, 	 forecast_errors=0.44371283526735517
# predicted=0.854293452523095, 	 expected=1.2915, 	 forecast_errors=0.4372065474769051
# predicted=0.8392056736820055, 	 expected=1.28213, 	 forecast_errors=0.4429243263179945
# predicted=0.8435021220186699, 	 expected=1.2728700000000002, 	 forecast_errors=0.42936787798133025
# predicted=0.8417036668543261, 	 expected=1.2715, 	 forecast_errors=0.429796333145674
# predicted=0.8360081425017083, 	 expected=1.26977, 	 forecast_errors=0.43376185749829177
# predicted=0.8358084029676495, 	 expected=1.27787, 	 forecast_errors=0.4420615970323506
# predicted=0.8274150459889253, 	 expected=1.2817100000000001, 	 forecast_errors=0.4542949540110748
# predicted=0.8298131194343532, 	 expected=1.26827, 	 forecast_errors=0.4384568805656468
# predicted=0.8392056736820055, 	 expected=1.2581, 	 forecast_errors=0.4188943263179945
# predicted=0.8408043893122906, 	 expected=1.25318, 	 forecast_errors=0.41237561068770934
# predicted=0.8487978675439897, 	 expected=1.25147, 	 forecast_errors=0.4026721324560104
# predicted=0.861587692505998, 	 expected=1.25403, 	 forecast_errors=0.392442307494002
# predicted=0.8582902415988078, 	 expected=1.25016, 	 forecast_errors=0.3918697584011921
# predicted=0.8670831775653763, 	 expected=1.23656, 	 forecast_errors=0.36947682243462376
# predicted=0.862187210867355, 	 expected=1.23642, 	 forecast_errors=0.3742327891326451
# predicted=0.8605883953173428, 	 expected=1.2429999999999999, 	 forecast_errors=0.3824116046826571
# predicted=0.8554925891655356, 	 expected=1.24984, 	 forecast_errors=0.39434741083446445
# predicted=0.8674829563926745, 	 expected=1.24512, 	 forecast_errors=0.37763704360732553
# predicted=0.8598889572290931, 	 expected=1.25807, 	 forecast_errors=0.39818104277090693
# predicted=0.8570912048760939, 	 expected=1.25597, 	 forecast_errors=0.3988787951239061
# predicted=0.8584901809723204, 	 expected=1.2512299999999998, 	 forecast_errors=0.3927398190276794
# predicted=0.8578905626912365, 	 expected=1.2482, 	 forecast_errors=0.39030943730876344
# predicted=0.8535940144348451, 	 expected=1.25029, 	 forecast_errors=0.39669598556515484
# predicted=0.8483981886364182, 	 expected=1.2556, 	 forecast_errors=0.4072018113635818
# predicted=0.8510960212625246, 	 expected=1.2632, 	 forecast_errors=0.4121039787374755
# predicted=0.8435021220186699, 	 expected=1.26413, 	 forecast_errors=0.42062787798133006
# predicted=0.8451009375686821, 	 expected=1.25753, 	 forecast_errors=0.41242906243131794
# predicted=0.8391056540353857, 	 expected=1.26841, 	 forecast_errors=0.4293043459646143
# predicted=0.8386060554009216, 	 expected=1.27073, 	 forecast_errors=0.4321239445990783
# predicted=0.8525948171659168, 	 expected=1.25394, 	 forecast_errors=0.40134518283408327
# predicted=0.8563917667878442, 	 expected=1.2571700000000001, 	 forecast_errors=0.4007782332121559
# predicted=0.8571911246029869, 	 expected=1.25032, 	 forecast_errors=0.39312887539701324
# predicted=0.8728785217251601, 	 expected=1.2494, 	 forecast_errors=0.37652147827483995
# predicted=0.8795732433467062, 	 expected=1.24682, 	 forecast_errors=0.36724675665329387
# predicted=0.8872669623977266, 	 expected=1.2442600000000001, 	 forecast_errors=0.3569930376022735
# predicted=0.8799729222542774, 	 expected=1.26633, 	 forecast_errors=0.3863570777457226
# predicted=0.8923628684692606, 	 expected=1.25766, 	 forecast_errors=0.3652971315307394
# predicted=0.8901647343973453, 	 expected=1.2607, 	 forecast_errors=0.3705352656026546
# predicted=0.8881663398594889, 	 expected=1.2525600000000001, 	 forecast_errors=0.3643936601405112
# predicted=0.8777746882626353, 	 expected=1.23902, 	 forecast_errors=0.36124531173736474
# predicted=0.879673163073599, 	 expected=1.2284700000000002, 	 forecast_errors=0.3487968369264012
# predicted=0.8769752305277658, 	 expected=1.23119, 	 forecast_errors=0.3542147694722342
# predicted=0.8923628684692606, 	 expected=1.22491, 	 forecast_errors=0.33254713153073934
# predicted=0.8945611024609027, 	 expected=1.2238200000000001, 	 forecast_errors=0.32925889753909743
# predicted=0.8950607010953668, 	 expected=1.2202600000000001, 	 forecast_errors=0.3251992989046333
# predicted=0.8954604799226651, 	 expected=1.2248700000000001, 	 forecast_errors=0.32940952007733504
# predicted=0.909648981221719, 	 expected=1.22716, 	 forecast_errors=0.31751101877828103
# predicted=0.9168432015580024, 	 expected=1.22937, 	 forecast_errors=0.3125267984419977
# predicted=0.9233379838060358, 	 expected=1.2282600000000001, 	 forecast_errors=0.3049220161939643
# predicted=0.9262357558056546, 	 expected=1.22796, 	 forecast_errors=0.3017242441943453
# predicted=0.9309319829696174, 	 expected=1.2155, 	 forecast_errors=0.2845680170303826
# predicted=0.930632223788939, 	 expected=1.21155, 	 forecast_errors=0.28091777621106095
# predicted=0.9297328463271766, 	 expected=1.2058799999999998, 	 forecast_errors=0.2761471536728233
# predicted=0.942422751562292, 	 expected=1.21569, 	 forecast_errors=0.2732672484377079
# predicted=0.9512155876091335, 	 expected=1.22817, 	 forecast_errors=0.2769544123908665
# predicted=0.927234853154856, 	 expected=1.23207, 	 forecast_errors=0.304835146845144
# predicted=0.9496169718985752, 	 expected=1.22599, 	 forecast_errors=0.2763730281014247
# predicted=0.9575105304033815, 	 expected=1.23024, 	 forecast_errors=0.2727294695966185
# predicted=0.9471189787262547, 	 expected=1.2224899999999999, 	 forecast_errors=0.27537102127374513
# predicted=0.9440213672728502, 	 expected=1.21793, 	 forecast_errors=0.2739086327271497
# predicted=0.9365273877558886, 	 expected=1.2385, 	 forecast_errors=0.3019726122441113
# predicted=0.9525145440587404, 	 expected=1.23999, 	 forecast_errors=0.28747545594125956
# predicted=0.9517152861633247, 	 expected=1.23979, 	 forecast_errors=0.28807471383667527
# predicted=0.9420230726547207, 	 expected=1.23642, 	 forecast_errors=0.29439692734527934
# predicted=0.9422228121887795, 	 expected=1.23053, 	 forecast_errors=0.28830718781122044
# predicted=0.9358279496676387, 	 expected=1.2287700000000001, 	 forecast_errors=0.2929420503323614
# predicted=0.9431221896505418, 	 expected=1.2331299999999998, 	 forecast_errors=0.290007810349458
# predicted=0.9340293945835679, 	 expected=1.23209, 	 forecast_errors=0.298060605416432
# predicted=0.9386258019403648, 	 expected=1.2289, 	 forecast_errors=0.2902741980596353
# predicted=0.9366274074025083, 	 expected=1.23553, 	 forecast_errors=0.29890259259749175
# predicted=0.9217392681757506, 	 expected=1.2332100000000001, 	 forecast_errors=0.31147073182424956
# predicted=0.9241374415409054, 	 expected=1.23438, 	 forecast_errors=0.31024255845909465
# predicted=0.9240375218140126, 	 expected=1.2471299999999998, 	 forecast_errors=0.3230924781859873
# predicted=0.9167432818311094, 	 expected=1.2528, 	 forecast_errors=0.3360567181688905
# predicted=0.9265354150666063, 	 expected=1.25631, 	 forecast_errors=0.32977458493339373
# predicted=0.9370269863903526, 	 expected=1.25187, 	 forecast_errors=0.3148430136096474
# predicted=0.9382260231130665, 	 expected=1.24981, 	 forecast_errors=0.3115839768869336
# predicted=0.9360277891214244, 	 expected=1.25641, 	 forecast_errors=0.32038221087857566
# predicted=0.9375265850248168, 	 expected=1.2528700000000002, 	 forecast_errors=0.31534341497518337
# predicted=0.9313315619574618, 	 expected=1.25055, 	 forecast_errors=0.31921843804253824
# predicted=0.9285338096044626, 	 expected=1.25803, 	 forecast_errors=0.32949619039553735
# predicted=0.9180422382807162, 	 expected=1.2591700000000001, 	 forecast_errors=0.34112776171928394
# predicted=0.9246370401753695, 	 expected=1.2564600000000001, 	 forecast_errors=0.3318229598246306
# predicted=0.9318311605919258, 	 expected=1.25993, 	 forecast_errors=0.32809883940807416
# predicted=0.9197409735576212, 	 expected=1.26302, 	 forecast_errors=0.34327902644237884
# predicted=0.9178423988269305, 	 expected=1.28157, 	 forecast_errors=0.36372760117306957
# predicted=0.9049527540577562, 	 expected=1.27579, 	 forecast_errors=0.37083724594224377
# predicted=0.9143452083856818, 	 expected=1.2854, 	 forecast_errors=0.3710547916143183
# predicted=0.9215395286416921, 	 expected=1.28986, 	 forecast_errors=0.3683204713583079
# predicted=0.9123468138478252, 	 expected=1.2987799999999998, 	 forecast_errors=0.3864331861521746
# predicted=0.9089495431334693, 	 expected=1.3134700000000001, 	 forecast_errors=0.4045204568665308
# predicted=0.9050527737043761, 	 expected=1.3116, 	 forecast_errors=0.406547226295624
# predicted=0.917542639646252, 	 expected=1.30466, 	 forecast_errors=0.3871173603537479
# predicted=0.9106482784103742, 	 expected=1.3047600000000001, 	 forecast_errors=0.39411172158962593
# predicted=0.9188415960958587, 	 expected=1.29677, 	 forecast_errors=0.3779284039041413
# predicted=0.9234380034526555, 	 expected=1.29797, 	 forecast_errors=0.3745319965473446
# predicted=0.9300326055078549, 	 expected=1.2929700000000002, 	 forecast_errors=0.36293739449214524
# predicted=0.9356282101335801, 	 expected=1.28987, 	 forecast_errors=0.35424178986641996
# predicted=0.9286337293313556, 	 expected=1.2871299999999999, 	 forecast_errors=0.3584962706686443
# predicted=0.9342292340373537, 	 expected=1.2912, 	 forecast_errors=0.3569707659626462
# predicted=0.9296330265200107, 	 expected=1.28568, 	 forecast_errors=0.35604697347998926
# predicted=0.9326305184070685, 	 expected=1.28813, 	 forecast_errors=0.35549948159293154
# predicted=0.9332300367684253, 	 expected=1.29139, 	 forecast_errors=0.35815996323157473
# predicted=0.9281342306166183, 	 expected=1.2904200000000001, 	 forecast_errors=0.36228576938338186
# predicted=0.9151446661205512, 	 expected=1.3014, 	 forecast_errors=0.38625533387944866
# predicted=0.9118472152133611, 	 expected=1.30332, 	 forecast_errors=0.39147278478663894
# predicted=0.8967594363722717, 	 expected=1.2966600000000001, 	 forecast_errors=0.3999005636277284
# predicted=0.8974587745407947, 	 expected=1.28824, 	 forecast_errors=0.39078122545920535
# predicted=0.8992573296248655, 	 expected=1.28706, 	 forecast_errors=0.3878026703751346
# predicted=0.9095490614948263, 	 expected=1.29236, 	 forecast_errors=0.38281093850517367
# predicted=0.8958600589105093, 	 expected=1.29493, 	 forecast_errors=0.39906994108949057
# predicted=0.8888656780280118, 	 expected=1.29447, 	 forecast_errors=0.40560432197198826
# predicted=0.890364473931404, 	 expected=1.30512, 	 forecast_errors=0.414755526068596
# predicted=0.8962597378180807, 	 expected=1.31154, 	 forecast_errors=0.41528026218191927
# predicted=0.893262245931023, 	 expected=1.3060399999999999, 	 forecast_errors=0.4127777540689769
# predicted=0.8862677651287982, 	 expected=1.3023, 	 forecast_errors=0.4160322348712018
# predicted=0.8832701733220136, 	 expected=1.30582, 	 forecast_errors=0.42254982667798635
# predicted=0.8761759726323501, 	 expected=1.29857, 	 forecast_errors=0.42239402736764986
# predicted=0.879673163073599, 	 expected=1.29722, 	 forecast_errors=0.41754683692640104
# predicted=0.8978584534483658, 	 expected=1.29331, 	 forecast_errors=0.39545154655163417
# predicted=0.9012557241627217, 	 expected=1.29367, 	 forecast_errors=0.3924142758372784
# predicted=0.8963596575449735, 	 expected=1.2902799999999999, 	 forecast_errors=0.3939203424550264
# predicted=0.9044532553430192, 	 expected=1.29601, 	 forecast_errors=0.39155674465698087
# predicted=0.8970590956332234, 	 expected=1.29587, 	 forecast_errors=0.3988109043667767
# predicted=0.8890655174817974, 	 expected=1.2942, 	 forecast_errors=0.4051344825182026
# predicted=0.8882662595863818, 	 expected=1.28314, 	 forecast_errors=0.3948737404136181
# predicted=0.8917634500276306, 	 expected=1.2795100000000001, 	 forecast_errors=0.38774654997236957
# predicted=0.8887657583011189, 	 expected=1.28134, 	 forecast_errors=0.392574241698881
# predicted=0.8882662595863818, 	 expected=1.27699, 	 forecast_errors=0.38872374041361824
# predicted=0.8836699521493119, 	 expected=1.27457, 	 forecast_errors=0.3909000478506881
# predicted=0.8826707548803836, 	 expected=1.2710299999999999, 	 forecast_errors=0.3883592451196163
# predicted=0.898258232275664, 	 expected=1.27083, 	 forecast_errors=0.37257176772433587
# predicted=0.9020550819778645, 	 expected=1.2703799999999998, 	 forecast_errors=0.3683249180221353
# predicted=0.8978584534483658, 	 expected=1.27342, 	 forecast_errors=0.3755615465516342
# predicted=0.8941615234730582, 	 expected=1.278, 	 forecast_errors=0.3838384765269418
# predicted=0.8970590956332234, 	 expected=1.27407, 	 forecast_errors=0.37701090436677664
# predicted=0.9031541989736855, 	 expected=1.2812299999999999, 	 forecast_errors=0.37807580102631433
# predicted=0.8920631092885822, 	 expected=1.28166, 	 forecast_errors=0.3895968907114178
# predicted=0.8870672228636678, 	 expected=1.28284, 	 forecast_errors=0.3957727771363322
# predicted=0.8935620051117015, 	 expected=1.28825, 	 forecast_errors=0.3946879948882984
# predicted=0.8941615234730582, 	 expected=1.29705, 	 forecast_errors=0.4028884765269418
# predicted=0.88986487529694, 	 expected=1.2971, 	 forecast_errors=0.4072351247030599
# predicted=0.892662727569666, 	 expected=1.2941799999999999, 	 forecast_errors=0.40151727243033386
# predicted=0.8907642527587023, 	 expected=1.29522, 	 forecast_errors=0.40445574724129774
# predicted=0.8848688889522989, 	 expected=1.2978100000000001, 	 forecast_errors=0.41294111104770126
# predicted=0.8855683270405486, 	 expected=1.29847, 	 forecast_errors=0.41290167295945146
# predicted=0.8815715379648357, 	 expected=1.30519, 	 forecast_errors=0.4236184620351644
# predicted=0.8754764346243735, 	 expected=1.30935, 	 forecast_errors=0.4338735653756265
# predicted=0.8744772373554452, 	 expected=1.30665, 	 forecast_errors=0.43217276264455484
# predicted=0.8787737856118365, 	 expected=1.29664, 	 forecast_errors=0.4178662143881635
# predicted=0.8835699325026921, 	 expected=1.29257, 	 forecast_errors=0.4090000674973079
# predicted=0.8830703338682281, 	 expected=1.29397, 	 forecast_errors=0.410899666131772
# predicted=0.8806723603425272, 	 expected=1.30049, 	 forecast_errors=0.41981763965747276
# predicted=0.8774749290819568, 	 expected=1.30729, 	 forecast_errors=0.4298150709180433
# predicted=0.8649849632203539, 	 expected=1.30762, 	 forecast_errors=0.4426350367796461
# predicted=0.8570912048760939, 	 expected=1.31613, 	 forecast_errors=0.4590387951239061
# predicted=0.8562919469806783, 	 expected=1.31629, 	 forecast_errors=0.4599980530193216
# predicted=0.8606884149639624, 	 expected=1.32275, 	 forecast_errors=0.46206158503603767
# predicted=0.8607882347711284, 	 expected=1.3226200000000001, 	 forecast_errors=0.4618317652288717
# predicted=0.8554925891655356, 	 expected=1.32433, 	 forecast_errors=0.4688374108344644
# predicted=0.8570912048760939, 	 expected=1.31877, 	 forecast_errors=0.4616787951239061
# predicted=0.8461000349178833, 	 expected=1.31841, 	 forecast_errors=0.47230996508211676
# predicted=0.846299874371669, 	 expected=1.3182, 	 forecast_errors=0.47190012562833106
# predicted=0.8464997138254546, 	 expected=1.32231, 	 forecast_errors=0.47581028617454546
# predicted=0.8544933918966074, 	 expected=1.32351, 	 forecast_errors=0.4690166081033925
# predicted=0.8484981083633111, 	 expected=1.32151, 	 forecast_errors=0.4730118916366889
# predicted=0.8504966028208945, 	 expected=1.31894, 	 forecast_errors=0.46844339717910555
# predicted=0.8506964422746801, 	 expected=1.32013, 	 forecast_errors=0.4694335577253199
# predicted=0.8433023824846113, 	 expected=1.31853, 	 forecast_errors=0.47522761751538867
# predicted=0.8538937736155237, 	 expected=1.3047799999999998, 	 forecast_errors=0.4508862263844762
# predicted=0.8547931510772859, 	 expected=1.30673, 	 forecast_errors=0.451936848922714
# predicted=0.862786629308985, 	 expected=1.31155, 	 forecast_errors=0.448763370691015
# predicted=0.8612879333253195, 	 expected=1.3080200000000002, 	 forecast_errors=0.4467320666746807
# predicted=0.8614876728593781, 	 expected=1.30635, 	 forecast_errors=0.4448623271406218
# predicted=0.8537939538083577, 	 expected=1.32708, 	 forecast_errors=0.4732860461916424
# predicted=0.8549928906113446, 	 expected=1.33423, 	 forecast_errors=0.4792371093886554
# predicted=0.8550928103382375, 	 expected=1.33808, 	 forecast_errors=0.48298718966176246
# predicted=0.8573909640567724, 	 expected=1.33043, 	 forecast_errors=0.4730390359432276
# predicted=0.8593893585946288, 	 expected=1.32884, 	 forecast_errors=0.4694506414053712
# predicted=0.8633861476703418, 	 expected=1.33749, 	 forecast_errors=0.47410385232965824
# predicted=0.8595891980484145, 	 expected=1.33118, 	 forecast_errors=0.47159080195158554
# predicted=0.8442016600266466, 	 expected=1.33118, 	 forecast_errors=0.4869783399733534
# predicted=0.8495972253591322, 	 expected=1.33209, 	 forecast_errors=0.4824927746408678
# predicted=0.84739899136749, 	 expected=1.33168, 	 forecast_errors=0.48428100863251
# predicted=0.847998609648574, 	 expected=1.33758, 	 forecast_errors=0.489581390351426
# predicted=0.8467994730061332, 	 expected=1.34628, 	 forecast_errors=0.4994805269938667
# predicted=0.837207279144149, 	 expected=1.34542, 	 forecast_errors=0.508212720855851
# predicted=0.8471991519137044, 	 expected=1.3490799999999998, 	 forecast_errors=0.5018808480862954
# predicted=0.8514957001700958, 	 expected=1.3566200000000002, 	 forecast_errors=0.5051242998299044
# predicted=0.8552926497920231, 	 expected=1.35768, 	 forecast_errors=0.5023873502079769
# predicted=0.8600887966828787, 	 expected=1.36418, 	 forecast_errors=0.5040912033171212
# predicted=0.8538937736155237, 	 expected=1.35127, 	 forecast_errors=0.4973762263844763
# predicted=0.8549928906113446, 	 expected=1.35824, 	 forecast_errors=0.5032471093886552
# predicted=0.8531944354470008, 	 expected=1.3521, 	 forecast_errors=0.4989055645529993
# predicted=0.8590896993336774, 	 expected=1.3396, 	 forecast_errors=0.4805103006663225
# predicted=0.8733781203596243, 	 expected=1.33622, 	 forecast_errors=0.4628418796403757
# predicted=0.8706803876532448, 	 expected=1.34049, 	 forecast_errors=0.4698096123467551
# predicted=0.871679584922173, 	 expected=1.34528, 	 forecast_errors=0.473600415077827
# predicted=0.8687819128422811, 	 expected=1.34517, 	 forecast_errors=0.47638808715771885
# predicted=0.8748769162630166, 	 expected=1.33615, 	 forecast_errors=0.4612730837369834
# predicted=0.8805723406959074, 	 expected=1.3365799999999999, 	 forecast_errors=0.4560076593040925
# predicted=0.8782741869773725, 	 expected=1.33501, 	 forecast_errors=0.45673581302262756
# predicted=0.8779744277966941, 	 expected=1.33871, 	 forecast_errors=0.46073557220330597
# predicted=0.8744772373554452, 	 expected=1.32785, 	 forecast_errors=0.4533727626445547
# predicted=0.8758761135319448, 	 expected=1.31879, 	 forecast_errors=0.4429138864680551
# predicted=0.8812717787841571, 	 expected=1.31908, 	 forecast_errors=0.43780822121584295
# predicted=0.8836699521493119, 	 expected=1.3061200000000002, 	 forecast_errors=0.4224500478506883
# predicted=0.8841694508640491, 	 expected=1.3060399999999999, 	 forecast_errors=0.4218705491359508
# predicted=0.8818712971455143, 	 expected=1.31371, 	 forecast_errors=0.43183870285448567
# predicted=0.8776746686160155, 	 expected=1.3055700000000001, 	 forecast_errors=0.4278953313839846
# predicted=0.8804724209690146, 	 expected=1.3017100000000001, 	 forecast_errors=0.4212375790309856
# predicted=0.8923628684692606, 	 expected=1.30251, 	 forecast_errors=0.41014713153073945
# predicted=0.893262245931023, 	 expected=1.305, 	 forecast_errors=0.41173775406897695
# predicted=0.8961599180109148, 	 expected=1.29659, 	 forecast_errors=0.40043008198908514
# predicted=0.9031541989736855, 	 expected=1.31059, 	 forecast_errors=0.4074358010263144
# predicted=0.9150446464739315, 	 expected=1.3003799999999999, 	 forecast_errors=0.3853353535260684
# predicted=0.9121469743940397, 	 expected=1.3044799999999999, 	 forecast_errors=0.3923330256059602
# predicted=0.9182420777345017, 	 expected=1.30329, 	 forecast_errors=0.38504792226549833
# predicted=0.9145450478394674, 	 expected=1.296, 	 forecast_errors=0.3814549521605326
# predicted=0.9178423988269306, 	 expected=1.3003799999999999, 	 forecast_errors=0.38253760117306923
# predicted=0.9150446464739315, 	 expected=1.3074299999999999, 	 forecast_errors=0.3923853535260684
# predicted=0.9153444056546101, 	 expected=1.29554, 	 forecast_errors=0.38019559434538985
# predicted=0.9139455294781105, 	 expected=1.2881200000000002, 	 forecast_errors=0.3741744705218897
# predicted=0.9114475363057899, 	 expected=1.29319, 	 forecast_errors=0.38174246369421017
# predicted=0.9124467335747182, 	 expected=1.28977, 	 forecast_errors=0.3773232664252819
# predicted=0.9092493023141477, 	 expected=1.2985200000000001, 	 forecast_errors=0.38927069768585243
# predicted=0.9163436029235382, 	 expected=1.2851700000000001, 	 forecast_errors=0.3688263970764619
# predicted=0.9127464927553965, 	 expected=1.28601, 	 forecast_errors=0.37326350724460355
# predicted=0.9073508275031841, 	 expected=1.2779, 	 forecast_errors=0.37054917249681596
# predicted=0.8882662595863818, 	 expected=1.28152, 	 forecast_errors=0.39325374041361816
# predicted=0.8852686677795971, 	 expected=1.2821799999999999, 	 forecast_errors=0.39691133222040276
# predicted=0.8966595166453789, 	 expected=1.2848, 	 forecast_errors=0.38814048335462104
# predicted=0.9073508275031841, 	 expected=1.2818200000000002, 	 forecast_errors=0.3744691724968161
# predicted=0.8979584730949857, 	 expected=1.28482, 	 forecast_errors=0.3868615269050144
# predicted=0.9148448070201458, 	 expected=1.29348, 	 forecast_errors=0.37863519297985415
# predicted=0.9071509880493985, 	 expected=1.29906, 	 forecast_errors=0.39190901195060157
# predicted=0.9115474560326827, 	 expected=1.3007799999999998, 	 forecast_errors=0.3892325439673171
# predicted=0.9212397694610135, 	 expected=1.30815, 	 forecast_errors=0.38691023053898643
# predicted=0.9237377626333341, 	 expected=1.30692, 	 forecast_errors=0.383182237366666
# predicted=0.9275346123355345, 	 expected=1.3099299999999998, 	 forecast_errors=0.38239538766446535
# predicted=0.9277345517090471, 	 expected=1.31098, 	 forecast_errors=0.383245448290953
# predicted=0.92713503334769, 	 expected=1.30341, 	 forecast_errors=0.37627496665231
# predicted=0.9149447267470386, 	 expected=1.3176, 	 forecast_errors=0.40265527325296147
# predicted=0.916943221204622, 	 expected=1.30305, 	 forecast_errors=0.386106778795378
# predicted=0.9225386259908932, 	 expected=1.30495, 	 forecast_errors=0.38241137400910685
# predicted=0.9232380640791429, 	 expected=1.30502, 	 forecast_errors=0.3817819359208572
# predicted=0.9180422382807161, 	 expected=1.3066200000000001, 	 forecast_errors=0.38857776171928404
# predicted=0.9114475363057899, 	 expected=1.29976, 	 forecast_errors=0.38831246369421013
# predicted=0.9178423988269305, 	 expected=1.3014, 	 forecast_errors=0.38355760117306936
# predicted=0.9193411947303229, 	 expected=1.3010700000000002, 	 forecast_errors=0.38172880526967723
# predicted=0.9149447267470386, 	 expected=1.3028899999999999, 	 forecast_errors=0.38794527325296124
# predicted=0.9183419974613947, 	 expected=1.30974, 	 forecast_errors=0.39139800253860524
# predicted=0.9188415960958588, 	 expected=1.31664, 	 forecast_errors=0.39779840390414123
# predicted=0.9215395286416921, 	 expected=1.3178299999999998, 	 forecast_errors=0.39629047135830775
# predicted=0.9134460307633734, 	 expected=1.30641, 	 forecast_errors=0.3929639692366267
# predicted=0.9114475363057899, 	 expected=1.31158, 	 forecast_errors=0.40013246369421007
# predicted=0.9027545200661142, 	 expected=1.30752, 	 forecast_errors=0.4047654799338858
# predicted=0.9118472152133612, 	 expected=1.30776, 	 forecast_errors=0.3959127847866388
# predicted=0.9097490008683389, 	 expected=1.31516, 	 forecast_errors=0.40541099913166123
# predicted=0.908549864225898, 	 expected=1.30411, 	 forecast_errors=0.3955601357741021
# predicted=0.904053476515721, 	 expected=1.29918, 	 forecast_errors=0.395126523484279
# predicted=0.9031541989736855, 	 expected=1.2974, 	 forecast_errors=0.39424580102631457
# predicted=0.899457268998378, 	 expected=1.29189, 	 forecast_errors=0.392432731001622
# predicted=0.8925627079230463, 	 expected=1.28852, 	 forecast_errors=0.39595729207695385
# predicted=0.8905643133851897, 	 expected=1.28813, 	 forecast_errors=0.3975656866148103
# predicted=0.8943612630071172, 	 expected=1.28378, 	 forecast_errors=0.38941873699288276
# predicted=0.8927625473768319, 	 expected=1.28817, 	 forecast_errors=0.3954074526231681
# predicted=0.8935620051117015, 	 expected=1.29051, 	 forecast_errors=0.39694799488829857
# predicted=0.9050527737043761, 	 expected=1.28578, 	 forecast_errors=0.38072722629562383
# predicted=0.9048528343308635, 	 expected=1.29326, 	 forecast_errors=0.3884071656691366
# predicted=0.9000566874400081, 	 expected=1.29298, 	 forecast_errors=0.3929233125599919
# predicted=0.9029544594396268, 	 expected=1.29283, 	 forecast_errors=0.3898755405603731
# predicted=0.9026547002589483, 	 expected=1.2854700000000001, 	 forecast_errors=0.3828152997410518
# predicted=0.89835805208283, 	 expected=1.29387, 	 forecast_errors=0.39551194791717004
# predicted=0.8953604602760453, 	 expected=1.30479, 	 forecast_errors=0.40942953972395457
# predicted=0.8987577309904012, 	 expected=1.29948, 	 forecast_errors=0.40072226900959873
# predicted=0.8930623065575104, 	 expected=1.30697, 	 forecast_errors=0.41390769344248957
# predicted=0.8945611024609027, 	 expected=1.3080200000000002, 	 forecast_errors=0.4134588975390975
# predicted=0.8947609419146884, 	 expected=1.30921, 	 forecast_errors=0.41444905808531163
# predicted=0.8812717787841571, 	 expected=1.3245, 	 forecast_errors=0.44322822121584293
# predicted=0.8834700127757993, 	 expected=1.32168, 	 forecast_errors=0.4382099872242007
# predicted=0.882470915426598, 	 expected=1.32564, 	 forecast_errors=0.443169084573402
# predicted=0.8844692100447276, 	 expected=1.33125, 	 forecast_errors=0.4467807899552725
# predicted=0.8789737249853492, 	 expected=1.33362, 	 forecast_errors=0.4546462750146508
# predicted=0.8832701733220136, 	 expected=1.33741, 	 forecast_errors=0.45413982667798636
# predicted=0.8793733039731936, 	 expected=1.33418, 	 forecast_errors=0.45480669602680635
# predicted=0.8781743671702067, 	 expected=1.3365200000000002, 	 forecast_errors=0.45834563282979346
# predicted=0.8783741067042654, 	 expected=1.3391899999999999, 	 forecast_errors=0.46081589329573447
# predicted=0.880872099876586, 	 expected=1.32936, 	 forecast_errors=0.4484879001234141
# predicted=0.8822709760530855, 	 expected=1.32182, 	 forecast_errors=0.43954902394691453
# predicted=0.8876667412250248, 	 expected=1.31221, 	 forecast_errors=0.42454325877497534
# predicted=0.8888656780280118, 	 expected=1.3118, 	 forecast_errors=0.4229343219719883
# predicted=0.8960599982840219, 	 expected=1.30805, 	 forecast_errors=0.411990001715978
# predicted=0.8923628684692606, 	 expected=1.3010899999999999, 	 forecast_errors=0.40872713153073925
# predicted=0.8902645542045113, 	 expected=1.30377, 	 forecast_errors=0.41350544579548876
# predicted=0.8876667412250249, 	 expected=1.3009, 	 forecast_errors=0.4132332587749751
# predicted=0.8950607010953668, 	 expected=1.30631, 	 forecast_errors=0.41124929890463324
# predicted=0.8896651357628813, 	 expected=1.2978, 	 forecast_errors=0.40813486423711876
# predicted=0.8899648949435597, 	 expected=1.3009, 	 forecast_errors=0.41093510505644026
# predicted=0.8918632698347964, 	 expected=1.29129, 	 forecast_errors=0.3994267301652037
# predicted=0.8986579111832355, 	 expected=1.2827, 	 forecast_errors=0.3840420888167645
# predicted=0.8937617446457601, 	 expected=1.28695, 	 forecast_errors=0.39318825535423996
# predicted=0.9045530751501851, 	 expected=1.27801, 	 forecast_errors=0.37345692484981496
# predicted=0.902854439793007, 	 expected=1.2975, 	 forecast_errors=0.39464556020699315
# predicted=0.9030542792467928, 	 expected=1.30958, 	 forecast_errors=0.40652572075320714
# predicted=0.9002565268937937, 	 expected=1.3069, 	 forecast_errors=0.4066434731062063
# predicted=0.9003564466206865, 	 expected=1.3061200000000002, 	 forecast_errors=0.4057635533793137
# predicted=0.8870672228636678, 	 expected=1.3161200000000002, 	 forecast_errors=0.4290527771363324
# predicted=0.8774749290819568, 	 expected=1.31244, 	 forecast_errors=0.43496507091804326
# predicted=0.8789737249853492, 	 expected=1.3108, 	 forecast_errors=0.43182627501465076
# predicted=0.8801726617883361, 	 expected=1.3139100000000001, 	 forecast_errors=0.43373733821166405
# predicted=0.8833700930489066, 	 expected=1.31845, 	 forecast_errors=0.43507990695109333
# predicted=0.8837697719564778, 	 expected=1.3222200000000002, 	 forecast_errors=0.4384502280435224
# predicted=0.8914636908469522, 	 expected=1.3200100000000001, 	 forecast_errors=0.4285463091530479
# predicted=0.9041534961623406, 	 expected=1.32761, 	 forecast_errors=0.4234565038376593
# predicted=0.8996571084521636, 	 expected=1.32762, 	 forecast_errors=0.4279628915478364
# predicted=0.8952605405491525, 	 expected=1.32612, 	 forecast_errors=0.43085945945084747
# predicted=0.8934619854650816, 	 expected=1.32613, 	 forecast_errors=0.43266801453491843
# predicted=0.8929624867503445, 	 expected=1.33009, 	 forecast_errors=0.4371275132496555
# predicted=0.8907642527587023, 	 expected=1.32059, 	 forecast_errors=0.42982574724129763
# predicted=0.8920631092885822, 	 expected=1.32685, 	 forecast_errors=0.43478689071141785
# predicted=0.8927625473768319, 	 expected=1.32572, 	 forecast_errors=0.4329574526231681
# predicted=0.8942614431999513, 	 expected=1.3304, 	 forecast_errors=0.43613855680004876
# predicted=0.8847689692254059, 	 expected=1.3335, 	 forecast_errors=0.448731030774594
# predicted=0.8827706746072765, 	 expected=1.3380100000000001, 	 forecast_errors=0.4552393253927236
# predicted=0.88137169851105, 	 expected=1.3341, 	 forecast_errors=0.45272830148895005
# predicted=0.8850687284060845, 	 expected=1.32988, 	 forecast_errors=0.4448112715939154
# ...
# predicted=1.4425708446045924, 	 expected=1.11306, 	 forecast_errors=-0.32951084460459246
# predicted=1.4432203228293958, 	 expected=1.1129200000000001, 	 forecast_errors=-0.3303003228293957
# predicted=1.4484461245458904, 	 expected=1.11684, 	 forecast_errors=-0.33160612454589034
# predicted=1.4424209650142534, 	 expected=1.12399, 	 forecast_errors=-0.3184309650142534
# predicted=1.4502147037118933, 	 expected=1.12506, 	 forecast_errors=-0.32515470371189337
# predicted=1.446617593543752, 	 expected=1.12201, 	 forecast_errors=-0.324607593543752
# predicted=1.455510449237213, 	 expected=1.12751, 	 forecast_errors=-0.32800044923721305
# predicted=1.463504027388639, 	 expected=1.1333, 	 forecast_errors=-0.3302040273886391
# predicted=1.4674008967374592, 	 expected=1.13104, 	 forecast_errors=-0.33636089673745917
# predicted=1.467500816464352, 	 expected=1.13253, 	 forecast_errors=-0.3349708164643519
# predicted=1.4530124560648925, 	 expected=1.1286100000000001, 	 forecast_errors=-0.3244024560648924
# predicted=1.460106756674283, 	 expected=1.12752, 	 forecast_errors=-0.33258675667428284
# predicted=1.4648029838382457, 	 expected=1.12071, 	 forecast_errors=-0.3440929838382456
# predicted=1.4610060342163185, 	 expected=1.1216899999999999, 	 forecast_errors=-0.3393160342163186
# predicted=1.4661019402878523, 	 expected=1.11932, 	 forecast_errors=-0.34678194028785225
# predicted=1.466301779741638, 	 expected=1.12252, 	 forecast_errors=-0.34378177974163804
# predicted=1.4834879727672037, 	 expected=1.1291200000000001, 	 forecast_errors=-0.35436797276720355
# predicted=1.4856862067588459, 	 expected=1.13681, 	 forecast_errors=-0.3488762067588458
# predicted=1.4846870094899176, 	 expected=1.13975, 	 forecast_errors=-0.34493700948991757
# predicted=1.483388053040311, 	 expected=1.1366, 	 forecast_errors=-0.3467880530403109
# predicted=1.4871850026622382, 	 expected=1.137, 	 forecast_errors=-0.3501850026622382
# predicted=1.4826886149520613, 	 expected=1.13687, 	 forecast_errors=-0.34581861495206123
# predicted=1.4839875714016677, 	 expected=1.13686, 	 forecast_errors=-0.3471275714016677
# predicted=1.4741454783027248, 	 expected=1.1285, 	 forecast_errors=-0.34564547830272474
# predicted=1.4633041879348534, 	 expected=1.1286, 	 forecast_errors=-0.33470418793485335
# predicted=1.4666015389223166, 	 expected=1.12771, 	 forecast_errors=-0.3388915389223166
# predicted=1.4761938327040274, 	 expected=1.1284, 	 forecast_errors=-0.3477938327040273
# predicted=1.4609061144894255, 	 expected=1.12242, 	 forecast_errors=-0.33848611448942556
# predicted=1.463504027388639, 	 expected=1.12135, 	 forecast_errors=-0.342154027388639
# predicted=1.4655124138991849, 	 expected=1.12073, 	 forecast_errors=-0.34478241389918485
# predicted=1.4711978463593864, 	 expected=1.125, 	 forecast_errors=-0.34619784635938644
# predicted=1.4655024219264954, 	 expected=1.12525, 	 forecast_errors=-0.3402524219264953
# predicted=1.4702985688173509, 	 expected=1.12693, 	 forecast_errors=-0.3433685688173509
# predicted=1.4633341638529211, 	 expected=1.12572, 	 forecast_errors=-0.3376141638529211
# predicted=1.4429205636487175, 	 expected=1.12096, 	 forecast_errors=-0.3219605636487175
# predicted=1.439783084224283, 	 expected=1.12235, 	 forecast_errors=-0.31743308422428296
# predicted=1.4413218480184322, 	 expected=1.12761, 	 forecast_errors=-0.3137118480184322
# predicted=1.4382243364847547, 	 expected=1.12194, 	 forecast_errors=-0.31628433648475474
# predicted=1.4327287515056495, 	 expected=1.12084, 	 forecast_errors=-0.31188875150564943
# predicted=1.4376747779868442, 	 expected=1.1151, 	 forecast_errors=-0.3225747779868442
# predicted=1.4394233732074686, 	 expected=1.11389, 	 forecast_errors=-0.32553337320746856
# predicted=1.448815827535394, 	 expected=1.11465, 	 forecast_errors=-0.33416582753539403
# predicted=1.4623149826386144, 	 expected=1.1124399999999999, 	 forecast_errors=-0.3498749826386145
# predicted=1.472496802808993, 	 expected=1.11443, 	 forecast_errors=-0.35806680280899306
# predicted=1.458727864443162, 	 expected=1.1154700000000002, 	 forecast_errors=-0.34325786444316186
# predicted=1.4715975252669578, 	 expected=1.10758, 	 forecast_errors=-0.36401752526695774
# predicted=1.4746950368006353, 	 expected=1.1084, 	 forecast_errors=-0.36629503680063524
# predicted=1.4740955184392783, 	 expected=1.1106, 	 forecast_errors=-0.3634955184392783
# predicted=1.4692993715484228, 	 expected=1.12022, 	 forecast_errors=-0.34907937154842283
# predicted=1.4703984885442436, 	 expected=1.12005, 	 forecast_errors=-0.3503484885442436
# predicted=1.465702261380281, 	 expected=1.11982, 	 forecast_errors=-0.345882261380281
# predicted=1.4802905415066332, 	 expected=1.11788, 	 forecast_errors=-0.3624105415066332
# predicted=1.4772929496998486, 	 expected=1.11978, 	 forecast_errors=-0.3575129496998486
# predicted=1.486585484300881, 	 expected=1.1213, 	 forecast_errors=-0.36528548430088104
# predicted=1.4799907823259548, 	 expected=1.11706, 	 forecast_errors=-0.3629307823259549
# predicted=1.4650028232920314, 	 expected=1.1137700000000001, 	 forecast_errors=-0.3512328232920312
# predicted=1.464003626023103, 	 expected=1.11066, 	 forecast_errors=-0.3533436260231031
# predicted=1.4617254562499469, 	 expected=1.10895, 	 forecast_errors=-0.3527754562499468
# predicted=1.4450188779134667, 	 expected=1.10776, 	 forecast_errors=-0.33725887791346665
# predicted=1.4627046695734964, 	 expected=1.10995, 	 forecast_errors=-0.35275466957349644
# predicted=1.4628045893003894, 	 expected=1.10839, 	 forecast_errors=-0.3544145893003894
# predicted=1.475394474888885, 	 expected=1.1079, 	 forecast_errors=-0.36749447488888487
# predicted=1.468000415098816, 	 expected=1.11368, 	 forecast_errors=-0.35432041509881596
# predicted=1.4779923877880983, 	 expected=1.10996, 	 forecast_errors=-0.3680323877880982
# predicted=1.4773928694267415, 	 expected=1.1089200000000001, 	 forecast_errors=-0.3684728694267414
# predicted=1.4859859659395243, 	 expected=1.1076700000000002, 	 forecast_errors=-0.3783159659395241
# predicted=1.4856862067588459, 	 expected=1.10558, 	 forecast_errors=-0.3801062067588459
# predicted=1.479890862599062, 	 expected=1.09889, 	 forecast_errors=-0.3810008625990622
# predicted=1.482788534678954, 	 expected=1.09666, 	 forecast_errors=-0.386128534678954
# predicted=1.46460314438446, 	 expected=1.09722, 	 forecast_errors=-0.36738314438445996
# predicted=1.463004428754175, 	 expected=1.10343, 	 forecast_errors=-0.3595744287541751
# predicted=1.448216309174037, 	 expected=1.10341, 	 forecast_errors=-0.344806309174037
# predicted=1.450414543165679, 	 expected=1.10261, 	 forecast_errors=-0.3478045431656789
# predicted=1.4518134193421786, 	 expected=1.1046200000000002, 	 forecast_errors=-0.3471934193421784
# predicted=1.4581083621364264, 	 expected=1.10428, 	 forecast_errors=-0.35382836213642643
# predicted=1.457309004321284, 	 expected=1.10099, 	 forecast_errors=-0.35631900432128405
# predicted=1.464003626023103, 	 expected=1.10625, 	 forecast_errors=-0.3577536260231031
# predicted=1.468000415098816, 	 expected=1.10722, 	 forecast_errors=-0.36078041509881587
# predicted=1.46530258247271, 	 expected=1.1000299999999998, 	 forecast_errors=-0.3652725824727101
# predicted=1.472496802808993, 	 expected=1.10719, 	 forecast_errors=-0.3653068028089932
# predicted=1.4711978463593864, 	 expected=1.1028799999999999, 	 forecast_errors=-0.3683178463593866
# predicted=1.4811898190486688, 	 expected=1.104, 	 forecast_errors=-0.37718981904866866
# predicted=1.4826886149520613, 	 expected=1.10175, 	 forecast_errors=-0.38093861495206127
# predicted=1.482788534678954, 	 expected=1.09924, 	 forecast_errors=-0.383548534678954
# predicted=1.4971769753515205, 	 expected=1.10195, 	 forecast_errors=-0.3952269753515205
# predicted=1.512065014658551, 	 expected=1.09414, 	 forecast_errors=-0.41792501465855114
# predicted=1.519558994175513, 	 expected=1.09195, 	 forecast_errors=-0.427608994175513
# predicted=1.517760439091442, 	 expected=1.0939299999999998, 	 forecast_errors=-0.42383043909144225
# predicted=1.5202584322637627, 	 expected=1.08974, 	 forecast_errors=-0.43051843226376274
# predicted=1.5214574689864766, 	 expected=1.0931, 	 forecast_errors=-0.42835746898647664
# predicted=1.526253615877332, 	 expected=1.09586, 	 forecast_errors=-0.43039361587733205
# predicted=1.5380441436506853, 	 expected=1.09628, 	 forecast_errors=-0.4417641436506854
# predicted=1.535346311024579, 	 expected=1.09759, 	 forecast_errors=-0.437756311024579
# predicted=1.5341472743018651, 	 expected=1.09702, 	 forecast_errors=-0.43712727430186504
# predicted=1.5334478362136155, 	 expected=1.0956, 	 forecast_errors=-0.43784783621361556
# predicted=1.5546308183148938, 	 expected=1.09703, 	 forecast_errors=-0.45760081831489385
# predicted=1.5630240753738909, 	 expected=1.10045, 	 forecast_errors=-0.46257407537389095
# predicted=1.566920944722711, 	 expected=1.10335, 	 forecast_errors=-0.463570944722711
# predicted=1.5725164494287092, 	 expected=1.10255, 	 forecast_errors=-0.46996644942870924
# predicted=1.5622247175587485, 	 expected=1.1031799999999998, 	 forecast_errors=-0.45904471755874865
# predicted=1.5622247175587485, 	 expected=1.1070799999999998, 	 forecast_errors=-0.45514471755874863
# predicted=1.5425405313608622, 	 expected=1.1123299999999998, 	 forecast_errors=-0.4302105313608624
# predicted=1.5429402102684335, 	 expected=1.1169, 	 forecast_errors=-0.42604021026843353
# predicted=1.542140852453291, 	 expected=1.11491, 	 forecast_errors=-0.42723085245329084
# predicted=1.5646227910041763, 	 expected=1.11242, 	 forecast_errors=-0.4522027910041764
# predicted=1.5842070574751697, 	 expected=1.11297, 	 forecast_errors=-0.47123705747516964
# predicted=1.5775124357733505, 	 expected=1.11035, 	 forecast_errors=-0.4671624357733506
# predicted=1.5793109908574212, 	 expected=1.10792, 	 forecast_errors=-0.4713909908574212
# predicted=1.5784117133153859, 	 expected=1.10991, 	 forecast_errors=-0.4685017133153859
# predicted=1.560825841382249, 	 expected=1.1110799999999998, 	 forecast_errors=-0.44974584138224905
# predicted=1.568219901172318, 	 expected=1.1149799999999999, 	 forecast_errors=-0.45323990117231805
# predicted=1.5675204630840682, 	 expected=1.11511, 	 forecast_errors=-0.4524104630840682
# predicted=1.5734157269707447, 	 expected=1.11645, 	 forecast_errors=-0.4569657269707448
# predicted=1.5707178943446385, 	 expected=1.1127, 	 forecast_errors=-0.45801789434463847
# predicted=1.570917733798424, 	 expected=1.10734, 	 forecast_errors=-0.46357773379842393
# predicted=1.5830080207524557, 	 expected=1.1065399999999999, 	 forecast_errors=-0.47646802075245587
# predicted=1.5740152453321017, 	 expected=1.10493, 	 forecast_errors=-0.4690852453321017
# predicted=1.5812094656683848, 	 expected=1.1018, 	 forecast_errors=-0.47940946566838494
# predicted=1.58280818129867, 	 expected=1.10325, 	 forecast_errors=-0.47955818129867
# predicted=1.5785116330422786, 	 expected=1.10083, 	 forecast_errors=-0.4776816330422786
# predicted=1.5943988696182376, 	 expected=1.10061, 	 forecast_errors=-0.49378886961823754
# predicted=1.5906019199963102, 	 expected=1.10202, 	 forecast_errors=-0.4885819199963102
# predicted=1.5812094656683848, 	 expected=1.10507, 	 forecast_errors=-0.47613946566838483
# predicted=1.5906219039416891, 	 expected=1.10713, 	 forecast_errors=-0.48349190394168917
# predicted=1.5986954178746289, 	 expected=1.10775, 	 forecast_errors=-0.49094541787462886
# predicted=1.5883037662777753, 	 expected=1.10719, 	 forecast_errors=-0.48111376627777536
# predicted=1.5685196603529963, 	 expected=1.10579, 	 forecast_errors=-0.46272966035299623
# predicted=1.5625244767394268, 	 expected=1.10178, 	 forecast_errors=-0.46074447673942687
# predicted=1.5655420524915902, 	 expected=1.10119, 	 forecast_errors=-0.4643520524915903
# predicted=1.5571288114872144, 	 expected=1.10202, 	 forecast_errors=-0.4551088114872144
# predicted=1.5621247978318558, 	 expected=1.0998, 	 forecast_errors=-0.46232479783185565
# predicted=1.547236758524825, 	 expected=1.10067, 	 forecast_errors=-0.44656675852482497
# predicted=1.5420409327263982, 	 expected=1.10151, 	 forecast_errors=-0.4405309327263982
# predicted=1.5494349925164672, 	 expected=1.10785, 	 forecast_errors=-0.4415849925164672
# predicted=1.5531320224115015, 	 expected=1.10809, 	 forecast_errors=-0.4450420224115015
# predicted=1.5391432606465063, 	 expected=1.10762, 	 forecast_errors=-0.43152326064650626
# predicted=1.5391432606465063, 	 expected=1.1103299999999998, 	 forecast_errors=-0.4288132606465065
# predicted=1.547736357159289, 	 expected=1.10584, 	 forecast_errors=-0.4418963571592891
# predicted=1.5550304972224651, 	 expected=1.1063, 	 forecast_errors=-0.44873049722246505
# predicted=1.5471368387979323, 	 expected=1.10914, 	 forecast_errors=-0.4379968387979323
# predicted=1.5469369993441464, 	 expected=1.1128799999999999, 	 forecast_errors=-0.43405699934414654
# predicted=1.5444390061718258, 	 expected=1.11286, 	 forecast_errors=-0.4315790061718259
# predicted=1.5577283298485716, 	 expected=1.11178, 	 forecast_errors=-0.4459483298485716
# predicted=1.5507339489660736, 	 expected=1.1143299999999998, 	 forecast_errors=-0.4364039489660738
# predicted=1.5644229515503905, 	 expected=1.115, 	 forecast_errors=-0.44942295155039047
# predicted=1.5791111514036356, 	 expected=1.11122, 	 forecast_errors=-0.46789115140363546
# predicted=1.572616369155602, 	 expected=1.11196, 	 forecast_errors=-0.46065636915560204
# predicted=1.576013639869958, 	 expected=1.10748, 	 forecast_errors=-0.468533639869958
# predicted=1.5767130779582077, 	 expected=1.10884, 	 forecast_errors=-0.46787307795820765
# predicted=1.5688194195336749, 	 expected=1.10877, 	 forecast_errors=-0.46004941953367484
# predicted=1.5638234331890337, 	 expected=1.10952, 	 forecast_errors=-0.45430343318903366
# predicted=1.5515333067812165, 	 expected=1.1172600000000001, 	 forecast_errors=-0.43427330678121634
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2187
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-97-df4e9325b69a> in <module>
#       1 # Print out predictions, expected and forecast error
#       2 for i in range(len(predictions)):
# ----> 3     print(f"predicted={predictions[i]}, \t expected={test[i]}, \t forecast_errors={forecast_errors[i]}")
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_value(self, series, key)
#     991
#     992         try:
# --> 993             return com.maybe_box(self, Index.get_value(self, series, key), series, key)
#     994         except KeyError:
#     995             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4734
#    4735             try:
# -> 4736                 return libindex.get_value_box(s, key)
#    4737             except IndexError:
#    4738                 raise
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds

# %%
# Plot predictions against known values
ax = expected.plot(legend=True, figsize=(12,6))
pd.DataFrame(predictions).plot(legend=True)
ax.autoscale(axis = 'x', tight=True)

# %%
from sklearn.metrics import mean_squared_error

error = mean_squared_error(test, predictions[:len(test)])
print(f'ARIMA(1,0,0) MSE Error {error}')
# Out:
# ARIMA(1,0,0) MSE Error 0.08362668727657686

# %%
from statsmodels.tools.eval_measures import rmse

error = rmse(test, predictions[:len(test)])
print(f'ARIMA(1,0,0) RMSE Error: {error:11.10}')
# Out:
# ARIMA(1,0,0) RMSE Error: 0.2891827922

# %% [markdown]
# #### Retrain the model on the full data, and forecast the future

# %%
model = ARIMA(eurusd['close'], order=(1,0,0))
results = model.fit()
fcast = results.predict(len(eurusd), len(eurusd)+365*5).rename('ARIMA(1,0,0)Forecast')

# %%
# Plot predictions against known values

ax = eurusd['close'].plot(legend=True, figsize=(12,6))
fcast.plot(legend=True)
ax.autoscale(axis='x', tight=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-2f673a7d9dbc> in <module>
#       2
#       3 ax = eurusd['close'].plot(legend=True, figsize=(12,6))
# ----> 4 fcast.plot(legend=True)
#       5 ax.autoscale(axis='x', tight=True)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     285
#     286         for ax in self.axes:
# --> 287             self._post_plot_logic_common(ax, self.data)
#     288             self._post_plot_logic(ax, self.data)
#     289
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _post_plot_logic_common(self, ax, data)
#     439
#     440         if self.orientation == "vertical" or self.orientation is None:
# --> 441             self._apply_axis_properties(ax.xaxis, rot=self.rot, fontsize=self.fontsize)
#     442             self._apply_axis_properties(ax.yaxis, fontsize=self.fontsize)
#     443
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _apply_axis_properties(self, axis, rot, fontsize)
#     523         if rot is not None or fontsize is not None:
#     524             # rot=0 is a valid setting, hence the explicit None check
# --> 525             labels = axis.get_majorticklabels() + axis.get_minorticklabels()
#     526             for label in labels:
#     527                 if rot is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1405         'Get the tick instances; grow as necessary.'
#    1406         if numticks is None:
# -> 1407             numticks = len(self.get_majorticklocs())
#    1408
#    1409         while len(self.majorTicks) < numticks:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1430         'Return the locations of the ticks'
#    1431         self.refresh()
# -> 1432         return self._locator()
#    1433
#    1434     def tick_values(self, vmin, vmax):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1609             return []
#    1610
# -> 1611         return self.tick_values(dmin, dmax)
#    1612
#    1613     def tick_values(self, vmin, vmax):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in tick_values(self, vmin, vmax)
#    1615         ymax = self.base.ge(vmax.year) * self.base.step
#    1616
# -> 1617         vmin = vmin.replace(year=ymin, **self.replaced)
#    1618         if hasattr(self.tz, 'localize'):
#    1619             # look after pytz
#
# ValueError: year 0 is out of range
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000021812688620> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~\Anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1201         renderer.open_group(__name__)
#    1202
# -> 1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1077         the axes.  Return the list of ticks that will be drawn.
#    1078         """
# -> 1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1430         'Return the locations of the ticks'
#    1431         self.refresh()
# -> 1432         return self._locator()
#    1433
#    1434     def tick_values(self, vmin, vmax):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1609             return []
#    1610
# -> 1611         return self.tick_values(dmin, dmax)
#    1612
#    1613     def tick_values(self, vmin, vmax):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in tick_values(self, vmin, vmax)
#    1615         ymax = self.base.ge(vmax.year) * self.base.step
#    1616
# -> 1617         vmin = vmin.replace(year=ymin, **self.replaced)
#    1618         if hasattr(self.tz, 'localize'):
#    1619             # look after pytz
#
# ValueError: year 0 is out of range
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1294         if minor:
#    1295             return self.get_minorticklabels()
# -> 1296         return self.get_majorticklabels()
#    1297
#    1298     def get_majorticklines(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1405         'Get the tick instances; grow as necessary.'
#    1406         if numticks is None:
# -> 1407             numticks = len(self.get_majorticklocs())
#    1408
#    1409         while len(self.majorTicks) < numticks:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1430         'Return the locations of the ticks'
#    1431         self.refresh()
# -> 1432         return self._locator()
#    1433
#    1434     def tick_values(self, vmin, vmax):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1609             return []
#    1610
# -> 1611         return self.tick_values(dmin, dmax)
#    1612
#    1613     def tick_values(self, vmin, vmax):
#
# ~\Anaconda3\lib\site-packages\matplotlib\dates.py in tick_values(self, vmin, vmax)
#    1615         ymax = self.base.ge(vmax.year) * self.base.step
#    1616
# -> 1617         vmin = vmin.replace(year=ymin, **self.replaced)
#    1618         if hasattr(self.tz, 'localize'):
#    1619             # look after pytz
#
# ValueError: year 0 is out of range

# %% [markdown]
# #### SARIMAX MODEL

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model  = SARIMAX(train['close'], order=(1,0,0), seasonal_order=(1,1,1,12), enforce_invertibility=False)
results = model.fit()
results.summary()

# %%
start = len(train)
end = len(train) + len(test)-1
predictions = results.predict(start = start, end = end, dynamic = False, typ='levels').rename('SARIMAX(1,0,0) Predictions')

# %%
# Compare predictions to expected values

for i in range(len(predictions)):
    print(f"predicted={predictions[i]}, expected={test['close'][i]}")

# %%
# Plot predictions against known values
ax = test['close'].plot(legend=True, figsize=(12,6))
predictions.plot(legend=True)
ax.autoscale(axis = 'x', tight=True)

# %%
from sklearn.metrics import mean_squared_error

error = mean_squared_error(test['close'], predictions)
print(f'SARIMAX(1,0,0) MSE Error {error}')

# %%
from statsmodels.tools.eval_measures import rmse

error = rmse(test['close'], predictions)
print(f'SARIMAX(1,0,0) RMSE Error: {error:11.10}')

# %% [markdown]
# #### Retrain Sarimax model

# %%
model = SARIMAX(eurusd['close'], order=(1,0,0), seasonal_order=(2,1,1,12), enforce_invinsibility=False)
results = model.fit()
fcast = results.predict(len(airline), len(airline)+365*10, typ='levels').rename('SARIMAX(1,0,0)Forecast')

# %%
# Plot predictions against known values

ax = eurusd['close'].plot(legend=True, figsize=(12,6))
fcast.plot(legend=True)
ax.autoscale(axis='x', tight=True)

# %%
#predict next value
predicted = StartARIMAForecasting(eurusdclose, 1,1,0)
#display the value
print('Predicted=%f' % (predicted))

# %%
#Get exchange rates
ActualData = eurusdclose
#Size of exchange rates
NumberOfElements = len(ActualData)

#Use 70% of data as training, rest 30% to Test model
TrainingSize = int(NumberOfElements * 0.7)
TrainingData = ActualData[0:TrainingSize]
TestData = ActualData[TrainingSize:NumberOfElements]

#new arrays to store actual and predictions
Actual = [x for x in TrainingData]

Predictions = list()

#in a for loop, predict values using ARIMA model
for timepoint in range(len(TestData)):
    ActualValue =  TestData[timepoint]
    #forcast value
    Prediction = StartARIMAForecasting(Actual, 3,1,0)    
    print('Actual=%f, Predicted=%f' % (ActualValue, Prediction))
    #add it in the list
    Predictions.append(Prediction)
    Actual.append(ActualValue)
#Print MSE to see how good the model is
Error = mean_squared_error(TestData, Predictions)
print('Test Mean Squared Error (smaller the better fit): %.3f' % Error)
# plot
plt.plot(TestData)
plt.plot(Predictions, color='red')

# %%
#Function that calls ARIMA model to fit and forecast the data
def StartARIMAForecasting(Actual, P, D, Q):
    model = ARIMA(Actual, order=(P, D, Q))
    model_fit = model.fit(disp=0)
    prediction = model_fit.forecast()[0]
    return prediction
